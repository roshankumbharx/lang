# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders.pdf import PyPDFLoader
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
loader = PyPDFLoader('../Data/RP1.pdf')

docs = list(loader.lazy_load())

docs
# Out:
# [Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='13 V May 2025\nhttps://doi.org/10.22214/ijraset.2025.70977'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3461 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \nPrepmania: an AI-Powered Mock Interview \nPlatform for Skill Evaluation and Performance \nFeedback \n \nSiddhi Awasare 1, Shreya Vedpathak 2, Shravani Pawar 3, Sanika Hatrote4, Sakshi Patil5, Mrs. K.A. Bhosale6   \n1,2,3,4,5Students, 6Assistant Professor ,Computer Science & Engineering, D Y Patil College of Engineering & Technology, Kolhapur, \nMaharashtra, India \n \nAbstract: Prepmania is an AI -powered mock interview platform designed to help job seekers prepare effectively for real \ninterviews. The name combines "Preparation" and "Mania," reflecting a passionate, focused approach t o interview readiness.  \nThe system generates role -specific questions based on user inputs like job title, skills, and e xperience. A key innovation is its \nmultimodal analysis— using facial expression recognition and voice analysis to assess confidence, communication, and behavior. \nPrepmania enhances preparation through AI -powered feedback, response comparison, and visual per formance analytics. It \nsimulates real interviews with timed questions and tracks progress across sessions. Built with Next. js, it uses Clerk for \nauthentication, Drizzle ORM for database handling, Tailwind CSS for UI, and Neon as its cloud database. \nKeywords: AI mock interview, Gemini API,  Video analysis, job specific questions, evaluation.  \n \nI. INTRODUCTION \nProposed an AI -based mock interview behavioral recognition system that simulates real -time interview scenarios using a virtual \nrecruiter. The system captures and analyzes multimodal inputs such as facial expressions, speech patterns, and emotional  responses \nto assess a candidate’s performance. It integrates machine learning models for emotion detection, pe rsonality recognition, an d \nsentiment analysis, providing users with detailed feedback and progress tracking across sessions. Their work highlights the potential \nof AI in improving interview preparedness by offering objective, data -driven insights into behavioral traits. This research lays the \ngroundwork for implementing intelligent virtual coaching systems in career readiness tools.  [1]. Prepmania advances this further \nthrough the integration of computer vision and speech processing algorithms to evaluate user perform ance accurately. Other \nresearch has examined the effectiveness of dynamic, chatbot -driven mock interviews that adapt depending on the user\'s response \nand track their performance over time — a function that informed Prepmania\'s personalized question generation and real -time \nperformance-monitoring functionality [2]. The platform leverages natural language processing (NLP) and machine learning \nalgorithms to analyze both verbal and non -verbal responses in real time. Key features include context -specific question generation, \nspeech recognition, sentiment analysis, and performance scoring. The system provides immediate feedback on various aspects  such \nas communication skills, confidence, body language, and technical knowledge. By offering personalize d and scalable support, t his \nAI-powered solution serves as an innovative tool in career development and recruitment preparation. [3]. \nInterview preparation is an essential part of job acquisition, especially in today\'s competitive job  mark ...
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3462 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \nII. RELATED WORK \nPrevious studies in the area of intelligent hiring technologies have shown promising outcomes in the  use of video and behavio ral \nanalytics to extend the assessment of candidates.  \nContemporary software like HireVue and MyInterview employs AI -driven video t ests to examine the facial expressions, tone of \nvoice, and speech of candidates. Such systems, however, are mainly developed for assessment from the  recruiter\'s perspective and \ndo not focus much on learning and monitoring development of candidates. \nConversely, Prepmania is user -oriented as it aims to improve interview preparation by means of an interactive online experience. \nThrough our site, we incorporate body posture analysis, voice measurement, and computer -mediated response analysis for the \npurposes of mimicking actual interview settings and providing constructive criticism to the user in real time. \nThe research "Efficacy and Benefits of Virtual Mock Interviews: Analyzing Student Perceptions of Dig ital Employment \nPreparations" by Indiana University of P ennsylvania\'s LeAnn Wilkie and Joseph Rosendale  [19] identifies the requirement of \nreplicating real interview procedures while providing complete, personalized critiques on nonverbal communication, response \ntiming, and content value. This outlook is consistent with Prepmania\'s aim to exactly replicate real interview situations and provide \nconstructive feedback. \nSimilarly, the research paper "AI -Based Mock-Interview Behavioral Recognition Analyst" by Kolpe, Patil, Deshmukh, Jeughale, \nand Misal emphasizes the  need for artificial intelligence systems that can accurately decipher nonverbal behavior, support va ried \ninterview styles, and offer end -to-end performance analysis [1]. Prepmania follows these recommendations by using AI models to \nexamine physical behavior and communication effectiveness in real time. \nThe paper titled "Conversate: Supporting Reflective Learning in Interview Practice Through Interacti ve Simulation and Dialogi c \nFeedback" by Taufiq Daryanto et al. (2024)  [18] presents a next-generation AI-driven interview simulation tool aimed at fostering \nreflective learning among users preparing for job interviews. Conversate utilizes state -of-the-art Large Language Models (LLMs ) \nsuch as GPT-3.5 and GPT-4 to not only simulate realistic interview conversations but also support learners in reviewing, analyzing, \nand improving their answers iteratively. \nThis research by P. K. Mishra, A. K. Arulappan, I. -H. Ra, T. M. L, G. R. G and Y. -S. Lee, "AI-Driven Virtual Mock Interview \nDevelopment," 2024 Joint 13th Inter national Conference on Soft Computing and Intelligent Systems and 25th International \nSymposium on Advanced Intelligent Systems (SCIS&ISIS), Himeji, Japan, 2024, pp. 1-4, doi:  \n10.1109/SCISISIS61014.2024.10760210 [16] contributes to the field by demonstrating the potential of AI in creating adaptive \nlearning environments, particularly in the context of professional skill development. The virtual mo ck interview system serves as a \ntool for users to engage in self -paced, reflective practice, ultimate ly aiming to boost confidence and competence in real -world \ninterview settings. \nShi, W., Wang, D. Empirical res ...
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3463 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \nIII. SYSTEM ARCHITECTURE \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nFig. 1 System Architecture of Prepmania \n \nThe PrepMania design is carefully  crafted to provide an AI-driven smooth mock interview experience  to practice, \nreceive immediate feedback, and track improvement over time. The key components and stages of the system are outlined below: \n1. User Authentication \n- Sign In: Users securely log in to access their personalized dashboard. \n2. Dashboard Access: After login, users are directed to a centralized dashboard where they can: \n- Initiate a new interview. \n3. Interview Setup: Users start by providing essential details: \n- Job Role \n- Key Skills \n- Years of Experience \n4.Start Interview: \n- After filling in the details, users proceed to initiate the mock interview. \n5. Question Fetching \n- Dynamic Question Generation: Interview questions are automatically fetched from the Gemini API, and tailored to the job \nrole, skills, and experience entered by the user. \n6. Answer Recording and Monitoring \n- Display Questions: Questions are presented one by one for the user to answer. \n- Answer Recording: Users record their spoken answers, while the system simultaneously: \no Converts speech-to-text using Speech-to-Text technology. \no Monitors body posture and hand gestures using MediaPipe models. \no Provides real-time prompts if improper posture or hand obstruction is detected.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3464 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \n7. Feedback Generation \n- AI-Based Analysis:  Each recorded answer is sent to the Gemini API , where AI evaluates the content and g enerates \nstructured feedback on: \no Relevance \no Clarity \no Confidence \n8. Data Storage \n- Database Integration: All user data is securely stored in a Neon PostgreSQL database through Drizzle ORM, including: \no Interview metadata \no Transcribed answers \no AI-generated feedback \n9. Feedback Display \n- Comprehensive Feedback Review: Upon completion of the interview, users receive detailed insights regarding: \no Answer quality \no Body language observations \no Performance trends compared to previous sessions \n10. Session Completion \n- Return to Dashboard: After reviewing feedback, users can return to the Dashboard to start new interviews or monitor \nprogress over time. \n \nFlowchart \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nFig 2: Flowchart of Prepmania'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 5, 'page_label': '6'}, page_content="International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3465 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \nIV. METHODOLOGY \n1) System Design: Prepmania uses a full-stack architecture: \n- Frontend: Built with Next.js and styled using Tailwind CSS for a responsive UI. \n- Backend: Handles API integrations, data processing, and scoring logic. \n- Database: Drizzle ORM with Neon stores user data and performance records. \n2) Authentication : User login and session management are powered by Clerk (Clerk Authentication is a modern, developer -\nfriendly authentication and user management service designed for web and mobile apps. It provides a complete set of features \nout of the box including) enabling secure access and personalized interview tracking. \n3) Dynamic Question Generation : Questions are generated using the Gemini API, based on user input (job role, skills, experience). \nResponses are saved for future comparisons. \n4) Audio-Visual Analysis \n- Voice: Analyzes volume and clarity using Web Audio API. \n- Posture: Tracks body posture using browser -based tools (e.g., face -api.js, MediaPipe). Suggestions are provided \nbased on heuristics. \n5) Answer Evaluation : User responses are transcribed and compared to Gemini-generated answers using keyword matching and \nstructure checks. A score is assigned based on similarity. \n6) Performance Feedback : Users receive feedback via: \n- Visuals: Charts showing a comparison of past and current interview performance. \n- Keyword Suggestions: Tips for improving delivery and presence. \n7) Timed Question Flow : Each question has a timer. If unanswered, the system automatically moves to th e next question. Timing \ndata is logged for analysis. \n8) Data Management : All user data, responses, and perfor mance metrics are securely stored in Neon and managed via Drizzle \nORM for efficient access and progress tracking. \n \nV. RESULTS AND EVALUATION \nThis table provides a performance analysis of an AI mock interview system across four batches (A, B,  C, D), with each batch \nconsisting of 25 students. The system's effectiveness is evaluated on several key metrics: \n1) System Performance: This includes the average question generation time and page load time for each b atch. The system \nconsistently performs with an average question generation time of around 1.8 seconds and page load times under 2 seconds. \n2) Question Quality: The relevance and balance of questions are assessed, with batches showing high rel evance ratings (ranging \nfrom 90% to 94%) and a well-balanced mix of technical and behavioral questions across all groups. \n3) Audio-Visual Analysis: The system tracks voice clarity, volume accuracy, and facial expression/posture to evaluate non-verbal \ncommunication. The accuracy of voice volume and facial expression analysis ranges fr om 81% to 85%, showing effectiveness \nin monitoring user confidence and communication. \n4) Answer Scoring: The system’s ability to evaluate answers is compared with human evaluation, achievin g high correlation \nscores (around 90% to 92%), indicating accurate assessments of the students’ responses. \n5) User Progress:  \nProgress is measured in three areas: \n\uf06c Voice Consistency: Improvements in maintaining voice clarity. \n\uf06c Answer Accuracy: Enhancement in the accuracy of responses. \n\uf06c Confidence/Posture: Improveme ...
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 6, 'page_label': '7'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3466 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \nCategory Metric Batch A \n(n=25) \nBatch B \n(n=25) \nBatch C \n(n=25) \nBatch D \n(n=25) \nOverall / \nSystem Avg \nSystem \nPerformance \nAvg. Question \nGeneration Time \n(sec) \n1.9 1.7 1.8 1.8 1.8 sec \nAvg. Page Load \nTime (sec) 2.0 1.9 1.8 1.7 < 2 sec \nQuestion \nQuality \nRelevance Rating \n(Avg %) 90% 93% 91% 94% 92% \nA mix of Technical \n& Behavioral High High High High ✔ Balanced \nAudio-Visual \nAnalysis \nVoice Volume & \nClarity Accuracy 81% 83% 82% 82% 82% \nFacial/Posture \nSuggestion \nEffectiveness \n80% 85% 82% 83% 80–85% \nAnswer \nScoring \nCorrelation with \nHuman Evaluation 90% 91% 92% 91% 91% \nUser Progress \nVoice Consistency \nImprovement +15% +17% +16% +16% +16% \nAnswer Accuracy \nImprovement +20% +22% +21% +21% +21% \nConfidence/ \nPosture \nImprovement \n+13% +15% +14% +14% +14% \nUser Feedback \nSatisfaction Rating  \n(out of 5) 4.5 4.6 4.6 4.7 4.6 / 5 \nEase of Use (out of \n5) 4.6 4.7 4.7 4.8 4.7 / 5 \nTimed Flow & \nVisual Feedback \nAppreciated by \nall \n Appreciated by \nall \nAppreciated by \nall \nAppreciated by \nall \n✔ Highly \nAppreciated \nTable 1 : Analysis of assessment conducted'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 7, 'page_label': '8'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3467 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \nIn summary, the analysis shows that the AI mock interview system is effective in improving interview performance, with consistent \nsystem performance, high -quality questions, accurate assessments, and significant improvements in student skills, all backed by \npositive user feedback.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 8, 'page_label': '9'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3468 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \n \nFig 3 : Graphical Representation \n \nVI. SNAPSHOTS \n \n \nSnapshot 1 : Question Section'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3469 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \n \nSnapshot 2 : Analysis of previous & current mock interview \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nSnapshot 3 : Feedback from Gemini AI & user answer \n \nVI. CONCLUSION \nThe article covered Prepmania, a web -based mock interview platform developed with Next.js in conjunction with a contemporary \nfrontend/backend tech stack. The platform combines functionalities such as question creation, multim odal analysis, visualization of \nperformance, and timed evaluations to provide immersive and educational interview practice. Prospect ive future enhancements \ncould involve a boost in real-time processing, broader API coverage, and support for adaptive difficulty in questions. \n \nREFERENCES \n[1] S. Kolpe, S. Patil, J. Deshmukh, S. Jeughale, and Y. Misal, "AI -Based Mock - Interview Behavioural Recognition A nalyst," International Journal for Research \nin Applied Science and Engineering Technology (IJRASET), May 2024. [Online]. Available: https://doi.org/10.22214/ijraset.2024.61427'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET) \n                                                                                           ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538 \n                                                                                                                Volume 13 Issue V May 2025- Available at www.ijraset.com \n     \n \n3470 \n©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 | \n \n[2] S. Rai, A. Miranda, S. Jagirdar, and N. Chitalia, “Skillup Bot: An AI Driven Mock Interview Platform,” IRJET, Apr.2024. [Online]. \nAvailable:https://www.irjet.net/archives/V11/i4/IRJET -V11I4385.pdf \n[3] A. Katakar, N. Kadam, S. Jagtap, and P. Hole, “Mock Interview System Using AI,”  IRJMETS,Oct.2024.[Online].Available:  \nhttps://www.doi.org/10.56726/IRJMETS6240  \n[4] H. R. Agashe, D. Anwat, P. Derle, P. Nagare, and S. Dhavale, "AI -Based Mock Interview Evaluator and Analysis," IJARSCT, Nov. 2023. [Online]. Available: \nhttps://ijarsct.co.in/Paper13645.pdf  \n[5] Balasaheb Jadhav ; Avadhut Sawant ; Arnav Shah ; Pranamya Vemula ; Abhijeet Waikar ; Srushti Yadav  “ A Comprehensive Study and Implementation of the \nMock Interview Simulator with AI and Pose -Based Interaction” [online] Available: https://ieeexplore.ieee.org/document/10530717  \n[6] Bharati Thawali , Pranjal Kalal, Samarth Dugam, Harshada Lokhande. “EmoConfident Interviewer :An AI Mock Interview Evaluato ” [online]  Available: \nhttps://www.ijraset.com/research -paper/emo-confident-interviewer-an-ai-mock-interview-evaluator \n[7] Mr. Shivam Mangesh Patil, Mr. Kapil Vikas Shinde, Mr.  Bhavesh Ganesh Vakare, Mr. Sandesh Sanjay Dunbale  “AI Powered Mock Interview Platform ” \n[online] . Available: https://www.ijirmps.org/research -paper.php?id=231993 \n[8] Latham, G. P., and Saari , L. M. (1984). “Applicant reactions to employment  interviews: A review of the  literature and research agenda. Journal of Applied  \nPsychology” 69(3), 400-410.[online] Available: https://issuu.com/irjet/docs/irjet -v11i1230 \n[9] McCarthy, J. D., Goffin, R. D., and  Kelloway, E. K.  (2020). The role of technology in interview  preparation. Human Resource Management Review,  30(4), \n100-112. [online] Available: https://www.irjet.net/archives/V11/i12/IRJET -V11I1230.pdf \n[10] Binns, R. S., Johnson, D., and Zhou, X. (2021).  “Artificial Intelligence in career development and job  matching. AI and Society, 36(2), 371 -385. , S. A., and \nImber, A. (2007). The effects of simulat ed interview  practice on performance.  International Journal of  Selection and Assessment, 15(1), 32 -42. [online] \nAvailable: https://www.irjet.net/archives/V11/i12/IRJET -V11I1230.pdf \n[11] Allen, D. G., and Ryan, A. M. (2003). Feedback and  performance improvement: A review of the literature.Organizational Behavior and Human Decision  \nProcesses, 91(2),186207. [online]Available: \nhttps://www.researchgate.net/publication/2855681_Organizational_Behavior_and_Human_Decision_Processe s \n[12] https://ieeexplore.ieee.org/document/10760 210 \n[13] https://www.researchgate.net/publication/390438737_Empirical_research_on_the_application_of_AI_mock_ interviews_in_enhancing_graduate_perceived_em\nployability_a_case_study_in_Hangzhou_China  \n[14] https://dl.acm.org/doi/10.1145/3701188  \n[15] https://open-publishing.org/journals/index.php/jutlp/article/view/738'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 11, 'page_label': '12'}, page_content='')]

# %%
len(docs)
# Out:
# 12

# %%
# chunking

splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=10,
)

chunk = splitter.split_documents(docs)

chunk
# Out:
# [Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='13 V May 2025\nhttps://doi.org/10.22214/ijraset.2025.70977'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET)'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='ISSN:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Volume 13 Issue V May 2025- Available at www.ijraset.com'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='3461'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Prepmania: an AI-Powered Mock Interview \nPlatform for Skill Evaluation and Performance \nFeedback'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Feedback'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Siddhi Awasare 1, Shreya Vedpathak 2, Shravani Pawar 3, Sanika Hatrote4, Sakshi Patil5, Mrs. K.A.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Mrs. K.A. Bhosale6'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='1,2,3,4,5Students, 6Assistant Professor ,Computer Science & Engineering, D Y Patil College of'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='of Engineering & Technology, Kolhapur,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Maharashtra, India'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Abstract: Prepmania is an AI -powered mock interview platform designed to help job seekers prepare'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='prepare effectively for real'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='interviews. The name combines "Preparation" and "Mania," reflecting a passionate, focused approach'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='approach t o interview readiness.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='The system generates role -specific questions based on user inputs like job title, skills, and e'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='and e xperience. A key innovation is its'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='multimodal analysis— using facial expression recognition and voice analysis to assess confidence,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='communication, and behavior.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Prepmania enhances preparation through AI -powered feedback, response comparison, and visual per'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='per formance analytics. It'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='simulates real interviews with timed questions and tracks progress across sessions. Built with'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='with Next. js, it uses Clerk for'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='authentication, Drizzle ORM for database handling, Tailwind CSS for UI, and Neon as its cloud'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='its cloud database.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Keywords: AI mock interview, Gemini API,  Video analysis, job specific questions, evaluation.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='I. INTRODUCTION'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Proposed an AI -based mock interview behavioral recognition system that simulates real -time'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='-time interview scenarios using a virtual'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='recruiter. The system captures and analyzes multimodal inputs such as facial expressions, speech'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='speech patterns, and emotional  responses'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='to assess a candidate’s performance. It integrates machine learning models for emotion detection,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='pe rsonality recognition, an d'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='sentiment analysis, providing users with detailed feedback and progress tracking across sessions.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='sessions. Their work highlights the potential'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='of AI in improving interview preparedness by offering objective, data -driven insights into'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='into behavioral traits. This research lays the'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='groundwork for implementing intelligent virtual coaching systems in career readiness tools.  [1].'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='[1]. Prepmania advances this further'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='through the integration of computer vision and speech processing algorithms to evaluate user'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='user perform ance accurately. Other'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='research has examined the effectiveness of dynamic, chatbot -driven mock interviews that adapt'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content="adapt depending on the user's response"),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content="and track their performance over time — a function that informed Prepmania's personalized question"),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='question generation and real -time'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='performance-monitoring functionality [2]. The platform leverages natural language processing (NLP)'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='(NLP) and machine learning'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='algorithms to analyze both verbal and non -verbal responses in real time. Key features include'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='include context -specific question generation,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='speech recognition, sentiment analysis, and performance scoring. The system provides immediate'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='immediate feedback on various aspects  such'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='as communication skills, confidence, body language, and technical knowledge. By offering'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='offering personalize d and scalable support, t his'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='AI-powered solution serves as an innovative tool in career development and recruitment preparation.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='[3].'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content="Interview preparation is an essential part of job acquisition, especially in today's competitive"),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='job  market. Traditional prep aration'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='techniques, such as mock interviews wit h peers or mentors, are subjective in feedback,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='feedback, intermittent, and not comprehensive in'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='assessment. These practices are most likely to yield little behavioral information, and it is'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='and it is diffic ult for candidates to tra ck their real'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='progress.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='To address these sho rtcomings, we present Prepmania — a computer -based mock interview platform,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='platform, built using Next.js and a'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='modern web stack. The platform delivers role -specific, user-profile-based interview questions and'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='and evaluates verbal and non -verbal'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='cues through multimodal an alysis, including body language, tone, and speech intelligibility. These'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='These behavioral signals help del iver'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='objective, real-time feedback to candidates, enabling them to identify improvement areas and'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='areas and enhance their interview readiness.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Prepmania does this by using a very detailed feedback dashboard that compares user responses with'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='with the best responses generated by'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='AI and displays progress in graphs and reports. This paper captures the system design, development'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='p rocess, and initial user'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='response for Prepmania. The findings set the potential of AI and web technologies to transform the'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='the interview preparation pro cess to'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='make it more streamlined, personalized, and evidence-based.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET)'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='ISSN:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Volume 13 Issue V May 2025- Available at www.ijraset.com'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='3462'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='II. RELATED WORK'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Previous studies in the area of intelligent hiring technologies have shown promising outcomes in'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='in the  use of video and behavio ral'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='analytics to extend the assessment of candidates.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Contemporary software like HireVue and MyInterview employs AI -driven video t ests to examine the'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='the facial expressions, tone of'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='voice, and speech of candidates. Such systems, however, are mainly developed for assessment from'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content="from the  recruiter's perspective and"),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='do not focus much on learning and monitoring development of candidates.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Conversely, Prepmania is user -oriented as it aims to improve interview preparation by means of an'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='of an interactive online experience.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Through our site, we incorporate body posture analysis, voice measurement, and computer -mediated'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='-mediated response analysis for the'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='purposes of mimicking actual interview settings and providing constructive criticism to the user in'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='user in real time.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='The research "Efficacy and Benefits of Virtual Mock Interviews: Analyzing Student Perceptions of'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='of Dig ital Employment'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Preparations" by Indiana University of P ennsylvania\'s LeAnn Wilkie and Joseph Rosendale  [19]'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='[19] identifies the requirement of'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='replicating real interview procedures while providing complete, personalized critiques on nonverbal'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='nonverbal communication, response'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content="timing, and content value. This outlook is consistent with Prepmania's aim to exactly replicate"),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='replicate real interview situations and provide'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='constructive feedback.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Similarly, the research paper "AI -Based Mock-Interview Behavioral Recognition Analyst" by Kolpe,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='by Kolpe, Patil, Deshmukh, Jeughale,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='and Misal emphasizes the  need for artificial intelligence systems that can accurately decipher'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='decipher nonverbal behavior, support va ried'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='interview styles, and offer end -to-end performance analysis [1]. Prepmania follows these'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='these recommendations by using AI models to'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='examine physical behavior and communication effectiveness in real time.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='The paper titled "Conversate: Supporting Reflective Learning in Interview Practice Through'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Through Interacti ve Simulation and Dialogi c'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Feedback" by Taufiq Daryanto et al. (2024)  [18] presents a next-generation AI-driven interview'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='interview simulation tool aimed at fostering'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='reflective learning among users preparing for job interviews. Conversate utilizes state -of-the-art'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Large Language Models (LLMs )'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='such as GPT-3.5 and GPT-4 to not only simulate realistic interview conversations but also support'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='support learners in reviewing, analyzing,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='and improving their answers iteratively.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='This research by P. K. Mishra, A. K. Arulappan, I. -H. Ra, T. M. L, G. R. G and Y. -S. Lee,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='-S. Lee, "AI-Driven Virtual Mock Interview'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Development," 2024 Joint 13th Inter national Conference on Soft Computing and Intelligent Systems'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Systems and 25th International'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Symposium on Advanced Intelligent Systems (SCIS&ISIS), Himeji, Japan, 2024, pp. 1-4, doi:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='10.1109/SCISISIS61014.2024.10760210 [16] contributes to the field by demonstrating the potential of'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='of AI in creating adaptive'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='learning environments, particularly in the context of professional skill development. The virtual'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='virtual mo ck interview system serves as a'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='tool for users to engage in self -paced, reflective practice, ultimate ly aiming to boost'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='to boost confidence and competence in real -world'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='interview settings.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Shi, W., Wang, D. Empirical research on the application of AI mock interviews in enhancing graduate'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='graduate perceived employability: a'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='case study in Hangzhou, China.  Educ Inf Technol  (2025) [17]. This study investigates the'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='the effectiveness of AI -powered mock'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='interviews in enhancing the perceived employability of university graduates in Hangzhou, China.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='China. Amid st a competitive job market'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='and increasing graduate numbers, the research aims to de termine whether AI -driven interview'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content="interview simulations can bolster graduates'"),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='confidence and readiness for employment. Participants reported a significant increase in their self'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='self -assessed employability after'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='undergoing AI mock interviews. The AI simulations contri buted to better performance in actual'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='in actual interview scenarios, suggesting'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='practical benefits beyond self-perception.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Also, sites like Interviewsby.ai show the growing demand for artificial intelligence -based mock'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='mock interviewing sessions. The site'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='provides topic -specific questions and provides user performance feedback based on AI. Efficient as'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='as they may be, mos t such'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='comparable sites are proprietary or do not support full multimodal testing. Prepmania addresses'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='addresses this requirement by combining real-'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='time question gene ration, body language monitoring, vocal analysis, and answer comparison in an'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='in an open, web -based environment'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='exclusively for students and job seekers.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Together, these studies identify the increasing ability of artificial intelligence to enhance'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='enhance interv iew read iness and provide key'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='lessons on which Prepmania is founded.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET)'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='ISSN:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='Volume 13 Issue V May 2025- Available at www.ijraset.com'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='3463'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='III. SYSTEM ARCHITECTURE'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='Fig. 1 System Architecture of Prepmania'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='The PrepMania design is carefully  crafted to provide an AI-driven smooth mock interview experience'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='to practice,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='receive immediate feedback, and track improvement over time. The key components and stages of the'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='of the system are outlined below:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='1. User Authentication \n- Sign In: Users securely log in to access their personalized dashboard.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='2. Dashboard Access: After login, users are directed to a centralized dashboard where they can:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='- Initiate a new interview. \n3. Interview Setup: Users start by providing essential details:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='- Job Role \n- Key Skills \n- Years of Experience \n4.Start Interview:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='- After filling in the details, users proceed to initiate the mock interview.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='5. Question Fetching'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='- Dynamic Question Generation: Interview questions are automatically fetched from the Gemini API,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='API, and tailored to the job'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='role, skills, and experience entered by the user. \n6. Answer Recording and Monitoring'),
# ...
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='frontend/backend tech stack. The platform combines functionalities such as question creation,'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='creation, multim odal analysis, visualization of'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='performance, and timed evaluations to provide immersive and educational interview practice.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='practice. Prospect ive future enhancements'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='could involve a boost in real-time processing, broader API coverage, and support for adaptive'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='adaptive difficulty in questions.'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='REFERENCES'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='[1] S. Kolpe, S. Patil, J. Deshmukh, S. Jeughale, and Y. Misal, "AI -Based Mock - Interview'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='Interview Behavioural Recognition A nalyst," International Journal for Research'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='in Applied Science and Engineering Technology (IJRASET), May 2024. [Online]. Available:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='https://doi.org/10.22214/ijraset.2024.61427'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='International Journal for Research in Applied Science & Engineering Technology (IJRASET)'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='ISSN:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Volume 13 Issue V May 2025- Available at www.ijraset.com'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='3470'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[2] S. Rai, A. Miranda, S. Jagirdar, and N. Chitalia, “Skillup Bot: An AI Driven Mock Interview'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Interview Platform,” IRJET, Apr.2024. [Online].'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Available:https://www.irjet.net/archives/V11/i4/IRJET -V11I4385.pdf'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[3] A. Katakar, N. Kadam, S. Jagtap, and P. Hole, “Mock Interview System Using AI,”'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='AI,”  IRJMETS,Oct.2024.[Online].Available:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='https://www.doi.org/10.56726/IRJMETS6240'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[4] H. R. Agashe, D. Anwat, P. Derle, P. Nagare, and S. Dhavale, "AI -Based Mock Interview'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Interview Evaluator and Analysis," IJARSCT, Nov. 2023. [Online]. Available:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='https://ijarsct.co.in/Paper13645.pdf'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[5] Balasaheb Jadhav ; Avadhut Sawant ; Arnav Shah ; Pranamya Vemula ; Abhijeet Waikar ; Srushti'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='; Srushti Yadav  “ A Comprehensive Study and Implementation of the'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Mock Interview Simulator with AI and Pose -Based Interaction” [online] Available:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='https://ieeexplore.ieee.org/document/10530717'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[6] Bharati Thawali , Pranjal Kalal, Samarth Dugam, Harshada Lokhande. “EmoConfident Interviewer'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content=':An AI Mock Interview Evaluato ” [online]  Available:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='https://www.ijraset.com/research -paper/emo-confident-interviewer-an-ai-mock-interview-evaluator'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[7] Mr. Shivam Mangesh Patil, Mr. Kapil Vikas Shinde, Mr.  Bhavesh Ganesh Vakare, Mr. Sandesh'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Sandesh Sanjay Dunbale  “AI Powered Mock Interview Platform ”'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[online] . Available: https://www.ijirmps.org/research -paper.php?id=231993'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[8] Latham, G. P., and Saari , L. M. (1984). “Applicant reactions to employment  interviews: A'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='A review of the  literature and research agenda. Journal of Applied'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Psychology” 69(3), 400-410.[online] Available: https://issuu.com/irjet/docs/irjet -v11i1230'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[9] McCarthy, J. D., Goffin, R. D., and  Kelloway, E. K.  (2020). The role of technology in'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='in interview  preparation. Human Resource Management Review,  30(4),'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='100-112. [online] Available: https://www.irjet.net/archives/V11/i12/IRJET -V11I1230.pdf'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[10] Binns, R. S., Johnson, D., and Zhou, X. (2021).  “Artificial Intelligence in career'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='in career development and job  matching. AI and Society, 36(2), 371 -385. , S. A., and'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Imber, A. (2007). The effects of simulat ed interview  practice on performance.  International'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Journal of  Selection and Assessment, 15(1), 32 -42. [online]'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Available: https://www.irjet.net/archives/V11/i12/IRJET -V11I1230.pdf'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[11] Allen, D. G., and Ryan, A. M. (2003). Feedback and  performance improvement: A review of the'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='of the literature.Organizational Behavior and Human Decision'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Processes, 91(2),186207. [online]Available:'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='https://www.researchgate.net/publication/2855681_Organizational_Behavior_and_Human_Decision_Process'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='on_Processe'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='s'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[12] https://ieeexplore.ieee.org/document/10760 210'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[13]'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='https://www.researchgate.net/publication/390438737_Empirical_research_on_the_application_of_AI_mock'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='of_AI_mock_'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='interviews_in_enhancing_graduate_perceived_em'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='ployability_a_case_study_in_Hangzhou_China  \n[14] https://dl.acm.org/doi/10.1145/3701188'),
#  Document(metadata={'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'source': '../Data/RP1.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='[15] https://open-publishing.org/journals/index.php/jutlp/article/view/738')]

# %%
len(chunk)
# Out:
# 379

# %%
# embedding of chunks to store in vector db

embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')

# %%
# db to store embeddings
vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory='chroma_chunks',
    collection_name='sample2'
)
# Out:
# C:\Users\ROSHAN\AppData\Local\Temp\ipykernel_13212\2296448774.py:1: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vector_store = Chroma(

# %%
# addings embeddings to db
vector_store.add_documents(chunk)
# Out:
# ['77d95c03-2428-48b8-9f8a-7cb38710019e',
#  'a68ea041-41b6-4067-806b-7006031c63d0',
#  '3d1d10fe-7861-40cb-a235-590225177cf2',
#  '46619b21-1275-4849-8b9e-987c864e7080',
#  '9ab4734b-15bd-40bf-8c63-2206faffe1ca',
#  '68371767-6ee7-439b-88b6-9c3a862b9371',
#  'bd0e0df2-f1ee-42c9-ba34-fe8cc60b150e',
#  '8dcebd81-9cb5-4c80-bdcc-6817ec7b3902',
#  '7bb82ef3-4489-4ebb-8f5c-013f948910dd',
#  'df51725d-7c79-400e-a460-e13075be9907',
#  '743b6fd9-9c75-4b50-bcf4-7a9322eeeac5',
#  'e1ab6feb-489e-4419-9150-ab72b79a51eb',
#  '0d94299b-8169-4299-8c1f-2d90ba94c529',
#  'e81cc53e-9866-4624-8d01-e65dc6e56211',
#  '3fac0c6a-3585-4af4-b837-94b1afc5d585',
#  '35fbaf65-6561-4e9c-9a89-213aeeda783a',
#  '6b4a076a-234a-4ddf-b4a5-95bdcf79dd23',
#  '8b138ecd-701d-4deb-91f6-fae6f0a45c54',
#  '5d5b0bc6-eb70-47ca-ba8b-832906fd2781',
#  'c8eef204-3e38-4d93-bc23-097b3daecc39',
#  '2b5fab67-5bbc-414b-a4bf-c856f4273ebc',
#  'fcdff695-aaa5-4ee4-9ae3-e23345c4abd0',
#  'fe79486b-8966-4eb5-a9cc-1a87eeab630a',
#  '79a4e224-9ada-4c62-be5a-3eacba5b9639',
#  '4c56ad74-4522-49e0-a7af-d8f85960ff04',
#  '595b1a01-b2b1-4b6d-a4f6-ec457482e57a',
#  '01f57ff2-bde0-4bd3-92c9-f62d9fe75a3d',
#  '1ecd25b7-ef84-481b-8098-4f9f57fd6ad7',
#  '8481bfd5-316c-4ead-acce-40f110e32b36',
#  '49c29ad2-a9f3-4548-bfeb-c722411b4de2',
#  'da25b48d-16b1-46f0-9280-33b2128b4f63',
#  'bc436dc9-08f7-43fd-a23a-f0804487e291',
#  '2b4aff88-d61c-464e-a72e-bc60ce5a0155',
#  '61ff3107-fa4f-465e-914b-4565066a1219',
#  '5aabf27c-f2b7-4a1f-acfb-426bd5bb056d',
#  '6858c145-ba0f-4f67-b700-1451b2236d34',
#  'ff9fe7e4-0f8b-4b69-a953-41cb5c6fa358',
#  '35f05ec4-6042-44b4-a297-d7d3805c57b8',
#  '4ccbdb2c-0758-43da-bf8c-6737919fd7a5',
#  '1d210583-82e4-40d9-b96b-4f5ffdbce01d',
#  '7911defc-6d7c-4eac-bb19-bb1607cecbd8',
#  'b5e7cf30-e415-40e7-8ada-8ed572da7f6f',
#  'b1f2ecf2-4330-4f54-948f-4992ad60ceae',
#  '4195a36a-f917-4b6c-a0a8-24eb207a160f',
#  '33dc5dd5-b10f-410f-a1b8-bd80775befb1',
#  '3224491d-0eb3-4294-9d39-480e28a987ed',
#  'dce3a14a-2edc-4156-b448-84e909fa5f97',
#  'a138ed5e-3499-4f01-81e7-8c17768e6681',
#  '5a176a21-ce64-45d5-ac27-0faa9244119e',
#  '9e3c0cd5-3a7c-4684-8a85-fcf6f090c892',
#  '7ecdd52e-2e51-4c23-b84b-679077502495',
#  'fb819501-d200-4b18-908d-fe2e807abb8c',
#  'eb0cc777-666a-442a-893a-3539f1ff0509',
#  '5b85968c-1af2-46c3-bf92-a5cd3d673c60',
#  '78a5850b-a3e3-442f-83be-1c637f7df6cb',
#  '4845a4d6-1915-41e5-82f9-7f88129d40ec',
#  '778a84e7-ba9e-4b3e-9114-c8d403a2f9d5',
#  '3782ff2c-4389-41e5-a37f-f166fd033586',
#  '4dedd623-a631-44d6-94a5-9d6dbb191ebb',
#  '08040b57-90b2-4128-9b56-b125ad71d691',
#  '44c8f948-5034-40bf-9259-5d3cfb2b84d7',
#  'a271487c-d535-49a3-96eb-560fd6ce7165',
#  'ed918ab2-5b5c-4158-b88c-a5532c975528',
#  '7da49ac0-4723-4b61-a38b-2324a869c0be',
#  '32d03ff8-0f3c-4021-9e03-f468256dc3b1',
#  '3adefce0-36a8-4d5c-9329-17a52fc18684',
#  'cbfffc4b-03fb-4d06-b192-d380e8d4bb13',
#  'a4ccb1c0-da66-442f-abb3-c4b62c16487c',
#  'b7c415c5-c657-40b4-9500-d567e4846ca2',
#  '37212e2a-914f-42ff-ae83-f10bd69cc275',
#  'a19b7cd7-da6b-4ff9-a3b4-2fb36197a440',
#  '2c984f26-91d3-4c58-b51d-f4ae3b74cc4f',
#  '74a6b80a-bb0f-4345-b617-4bb4183f209a',
#  '63a6db26-c0ad-4ecd-abb0-ea247be30761',
#  'fc74d8c6-4a18-4007-8139-7222b10616e9',
#  'cd08429e-869c-42b4-87e0-70b43fe7c59f',
#  '7e413480-873f-474b-8e6d-4a3c9e519a64',
#  '11e085cd-6ac6-40d5-9787-4883173a5276',
#  '63284745-4aae-4cc6-a0a4-9898fe9e7dab',
#  'b89a0551-77a9-4ba9-9411-e92f05748eff',
#  '12e9ee8d-0b73-413f-bafe-6acc2df254ed',
#  '9c0c67be-4ad6-4ca1-9050-40e0b7ecf6c5',
#  'bf43de09-26e6-4b36-b39a-b16c29a25027',
#  'afddf46c-e4a8-446a-bb89-2f39b6487d74',
#  '59d5e485-8f89-4246-bd0a-150515a0ae51',
#  '477939bc-99a8-429e-9d6d-8d4236e13a42',
#  'bb5d9a0b-3600-4c52-b6f9-366072af6764',
#  '75d3dc47-af34-4b68-b92f-65577aed67fd',
#  '1f441288-f871-452a-8b84-9f621f8fbd8d',
#  '90bc1bf0-7aac-4d46-b758-f9584f633a91',
#  '07c1df5d-c41a-4c4f-998f-e42ad63fdbd2',
#  'acfe2575-cb10-4bcc-8811-54290a4fcb4e',
#  'a04f5fa7-8433-42fc-ae95-a8e0d402ccbc',
#  'e9409a85-867c-439c-8b12-f9513556e97a',
#  '508e72a1-e847-42e3-954b-2c3afae13a08',
#  '2cfe2402-2664-460e-8cb0-d51cfaaf8b97',
#  '5bcde254-b003-41ce-8351-1be06bfd1806',
#  '1f0db402-4123-4b2d-b57c-3ddadbf84972',
#  '4f23618e-acee-4594-93a6-a9e00bae6f5b',
#  '0dc98efc-9b29-4d4f-b332-43b26b2b02dd',
#  'b312b49a-790a-4c88-bf78-f3a467efbff1',
#  '5469b023-5726-4daf-8897-106ed47055dd',
#  'f389cfc2-2fb3-4884-ac08-ac6e166929df',
#  '150173e3-9a43-48e5-b99a-72a941b825a0',
#  'a380363d-8383-4443-99b5-b86321afa0ad',
#  'c00dea64-04bf-40ac-b516-592c10846455',
#  'ec757299-0428-4cad-bb4b-874cb5ec254d',
#  '3053ae5f-f7d7-4896-96d2-20f319e059de',
#  'ce3985ee-139e-491c-bde5-736618630819',
#  '120ecba9-e230-4d18-943b-de540ed6a9ae',
#  '7d91719c-9930-43f1-a13a-13979779d1ef',
#  'bec885d5-e406-46f9-be12-fe8625409deb',
#  '8da2fb50-2d57-4307-bfb3-ef5913a58b1f',
#  'a27fe1ac-63b9-4dab-b8ad-50f3cb9df609',
#  'a563d193-788a-4eca-8c92-3e5fe090eede',
#  '1f663bc9-3af3-4002-8205-f859883a2c2c',
#  '92744e23-724a-4cec-bd4e-75ebe86fd074',
#  '8e3925ab-1486-49c4-80e6-5534e5ef9640',
#  '4a4af489-0683-4140-bfbc-62d76bb6cd84',
#  '6360b534-c938-43b4-90d4-86e6e8830c6a',
#  '124305f5-8e94-427d-bc6d-95bbd52c62d6',
#  'ad5b819c-5ef0-43d1-8e02-8944530d5fa5',
#  'ed02507c-765e-4d80-a56b-97b04dba0a23',
#  '14e4a301-8aff-4c26-81fb-b607c94a07bf',
#  'dc2b5ea2-d520-4da4-98cf-f690dbe64c7b',
#  '8ec5503d-133b-45e0-83ce-9d9694132655',
#  'f7616452-c051-4113-a911-6597acaba95a',
#  'f2ec3868-eb65-4278-afe3-f93b3b05f696',
#  '9776a71f-124f-4e16-b66d-52d821d0e173',
#  'a79c07bd-85f1-4dd5-ba3f-bfac76258f17',
#  'a14eca47-c77e-4a90-87a6-693f1ed9fdfb',
#  '9773dcfc-fa66-4756-a308-f03f7497f11e',
#  '95f50d98-9009-4d20-b4ab-9d22434da4c5',
#  '7888a897-f267-491b-a87d-07847d0ff6c2',
#  '139ab0aa-c2b8-4adb-bf8f-6d7c112ebea4',
#  '172652a9-1ba5-4855-bb89-3b0c543a2149',
#  '4939e331-511e-4cd0-986d-ce4581c21e8a',
#  '8c79e799-b641-4c5e-be58-3ab3ef4af766',
#  '3f75ec80-b249-4039-9ad8-2f7d1d18bede',
#  '05f5899f-11ec-4eac-b298-51507a8f053b',
#  'f3ea8dd0-d8df-4c13-b2be-e9c896258e42',
#  'e027453c-d1c1-45f1-a583-ad197fe0b6b9',
#  '2e394bea-21f1-4428-8c64-e5affbf0dfd5',
#  '6e17eb78-6626-4e28-acb5-0490be4fb1ae',
#  '1277f95b-fd74-46aa-8fab-60d96eff1f18',
#  'c7c87f0e-fa95-40af-abfb-122fe42026f9',
#  '0f6da4ba-24c3-46a7-a6fb-a3f05fa91920',
#  '4bfd80a2-4f7b-49e9-9faa-a24a717637d5',
#  '283e035e-d18e-4b38-b35a-df8bc2622cd7',
#  '12e31772-7a02-4388-aa01-856d2cdab22f',
#  'aa1811f5-c908-48d5-b981-6cd073af4e3c',
#  '7b0ad667-1046-4e4b-9212-08997186283e',
#  '98333ed5-a32e-42bf-a84e-098d4690310d',
#  '53f7e531-fd92-4803-9724-2db4e684fcfb',
#  '938cf263-62cb-49a4-bfa7-d97fb5d70f9f',
#  '3a389dc0-5779-489e-8a57-cd5b9103d565',
#  '22942a0d-62d5-4ae4-b79e-dbd628d41a41',
#  '3d376b0c-8487-445e-ad48-d2453e04dd47',
#  'e200b8f6-44c5-4bf4-9875-1ab9447c07ff',
#  '2db4d1ff-a60c-49c7-b667-03f601d1c928',
#  'f477709b-6356-479e-8fbf-5c7f5d472316',
#  '15bb556c-e753-42d7-8c36-441eabd8f60b',
#  '8386d211-2cc2-4cb0-bc71-08bc8ec914f8',
#  '029c53d4-fe82-4812-a4a3-b631a3922d86',
#  'c8d63f59-40f2-4de3-90aa-dc9438c2d65d',
#  '7bb33e84-c91d-456d-8406-5b3fc8ebca85',
#  '20381372-c2bc-4df3-b4c6-fbc4cc6bfee5',
#  'da23852f-ec48-4eda-94ab-e9c84ea50fab',
#  'bf899a80-e235-444c-aecb-0b620095a64f',
#  '5dd13de1-5fa0-4474-ac8c-7368a19d0f8c',
#  'f9b23cad-7c5f-4084-8323-14c961cb2347',
#  '46ec03f4-6b05-443f-9552-eefd2d867c56',
#  '6a86edfc-5288-49e9-8087-56a4cc06906f',
#  '20ef1b41-44d6-423d-b21a-4ca346d08ea1',
#  'ec6ab86b-08f9-42fd-b2c8-d3d9def54b27',
#  '10134743-c94d-4316-b78d-6a4ede58bfe0',
#  'd86f9a77-7878-466b-bf75-943e55c0aa22',
#  '316d44cc-0fb1-48ac-bf93-75e509dc80fe',
#  '65473940-5a1e-4c32-9e7d-a07939cb25fa',
#  '8d238b06-4637-4e2a-9054-88c160eefca0',
#  '76d4842f-473a-49f9-8866-6c97ac1b3308',
#  '404b53f7-f4b0-4d76-9371-de363f64a5d9',
#  '38abaf3b-e95a-4cb3-ada8-00fd205dcf2e',
#  'be39a790-dfb2-4f72-9eec-81edbf25e773',
#  '61acbe7c-017a-44b3-96aa-c99387d5439d',
#  '6474d13c-1a52-46d8-a250-e559fd6300c8',
#  'e097a478-bc9a-4d14-aad1-e7493a17c646',
#  'f19876b4-2393-4975-93c5-42859a788f8b',
#  'f488e90b-49db-4048-88b4-1de90910794e',
#  '71fc1bbc-7bae-4db5-b097-d9f933cef5ed',
#  '10c99b33-b01f-4f2f-9ef1-3ec8e1a1574d',
#  '94b99edc-a73b-45c5-a0de-12f46547297f',
#  'ad501abe-084d-4354-b072-a890f25e0e58',
#  '0ed4f087-1f15-46e9-9cd8-03b764f37df1',
#  'adc4ef38-e735-4484-bc6d-8ca6f00c1d99',
#  'e123bb82-d5a5-4a77-b3d2-2dbaadd6661d',
#  'e0eb0efa-21a8-4ef2-ac45-49319bfcb5fb',
#  'b34bd359-a8f4-4ee7-a3f6-e4f3178053fd',
#  'ff097d2e-8005-47ea-bc49-eb5894e998c7',
#  '3b595b2b-f4e3-4e97-9a02-dd0636489972',
#  'ae628234-a576-4c6c-a454-5c921224228b',
#  'e5b41aea-80b7-474b-ae85-9413e69be775',
#  '0a918a8a-da1f-48c3-9383-022d17ca41b5',
#  'c2f5a0a1-6046-48c7-931e-244ea1425d4a',
#  'a55de50d-67d5-4649-9834-a045b428d615',
#  'a8c6fc10-cc06-4ee8-8c8b-c70a342dbafe',
#  '1976ea90-0cc0-49ad-8dfd-66646607f96a',
#  '5eeeb35b-3a96-431c-a9ff-0088233fbe8e',
#  '35de4336-198a-4d30-b013-f01cbc129691',
#  '071a17e6-2e1a-40c4-88af-1c39151df74a',
#  'c596be3f-b047-4500-8d61-2c203cf93721',
#  '33d232f8-2cb6-46e3-87b8-f42a33a86b56',
#  'a590ebf7-61ae-44cc-b882-22eea4f89bb0',
#  '3491c91d-ce61-4894-b7b9-67040286f42e',
#  '1eac6f32-2d8a-4cd1-ab3a-3083b27c268a',
#  '00ddf7cd-8b5b-4e0d-ba0c-30e702475670',
#  'a51d0948-883f-4e72-86ff-1397ca45a412',
#  'ca72af2a-2238-403d-aae9-c2081932e15a',
#  '730a4dc0-82bf-44b9-897d-0ba30f3be188',
#  '6e85ef12-7857-45d7-a505-a516111f6f93',
#  '309a237f-68e8-4fb8-a1d8-0811c75ce2dd',
#  '625ea9e8-51d6-479b-8aa0-6849dc8634de',
#  'c5bfaa60-3854-4026-8ac6-324a7193c492',
#  '8a57be10-eb80-4d3f-871f-3eb22e34e761',
#  '0977128d-6e4b-4ae7-a13e-fac6b1199e4e',
#  '10048c3e-3692-46c8-8c28-7c88a3f8fb9a',
#  '88de30fe-a899-4262-b5aa-2e48ba18f474',
#  '5fbbd0bd-3cbf-4186-afaa-efd24e261f13',
#  '6f7e74cd-9bde-4c5b-8157-5f38f12e7c56',
#  '0c16131f-cc16-4bd7-b263-f4b58a6b5329',
#  'a4594418-b88c-43f4-8607-843974acd82e',
#  '54cc48bf-d77e-4cc0-bf5e-9cf9aeaf4e41',
#  'af2590f2-8f52-4b66-b238-4354de531217',
#  '92213614-22bb-47ef-ba02-31ae6e5b6ff9',
#  'f3bf4275-09b6-4670-8e98-72481a6e70d6',
#  '12f0286e-e471-4146-bf3c-da374c593ab9',
#  'c5ddfac6-f243-4961-b7d1-74bc5aa7844e',
#  '52561e08-ea60-4f60-a4af-3f50495cad0e',
#  '6a16b71f-afce-45cd-9ab9-3049a9ffb997',
#  '5963ded3-c770-48b3-bd41-b9c1ee7b2743',
#  'e8537838-3ca9-4425-b79f-39bce7a65dcc',
#  '2c0edf24-24a4-4bc1-9445-861292ad7e98',
#  'f65de4e4-fa68-46a2-a4de-da800318be64',
#  '782fd5db-b7a1-4463-b4e0-f9517a3ee161',
#  'e845a8a0-312f-430a-bb63-4b6860f7670b',
#  '6be91ddf-b37a-48af-ab3a-da75a5cb78c8',
#  'eb15b9ce-5aa1-4147-9913-d891ac55e8b2',
#  '8d3f27ec-d2e2-48ba-9483-382e67ceb3eb',
#  '7a5175ed-28b0-4ad0-a1e9-1f07cc678da2',
#  'e9e14d79-3b2d-4bd7-b0fa-5136303fc09e',
#  'ff1c04d5-f340-42e8-922b-164feedbe056',
#  '3c31cd4a-d998-4f63-8821-0198dc66a523',
#  '92dcaa38-0343-4169-bf80-406fd5ba341e',
#  '2033d6a9-96af-4639-880f-e20d1bce5290',
#  '08d248a3-d22b-4edb-862b-99e8ce83b5af',
#  'f10bb92b-fe84-4316-a261-4dfb5c530817',
#  '2cb4b811-9f0e-40b0-a1c6-6e89c7d8565d',
#  'b7a0280a-7dda-451d-b6fe-2379763d1fe4',
#  '87ba3ae9-1ccc-458c-af22-9efc505c373a',
#  '968cf8a6-847c-492c-b031-447cb4c9f547',
#  '047f94c6-518a-4d4b-ad3b-f3280b55c5b7',
#  'b9467859-82c2-4790-a67e-0e564891d19e',
#  '89caffe9-e42f-487c-8f49-c72c80861497',
#  '71e757b6-58a8-468b-8571-82f0f996a318',
#  '0fbbba82-b6ae-4c7b-99a0-2220a92752f2',
#  '8e301965-9af1-4a34-a692-fa9e112d19a4',
#  '2bfcac1b-b56e-4711-be0c-0d3efa57a315',
#  'b355820f-0407-4d90-9a60-8195a0474267',
#  '9403588a-617a-47a4-bf5d-10f9258ae58c',
#  'fb016668-734f-4edb-a16c-6562bf73e83d',
#  '81db6a9c-58b0-40a7-ad9c-f86089c26398',
#  '97e9c560-8a76-40c2-9a42-68adde53321b',
#  '313f7f0a-0bed-4f3d-a132-9b3c01c9f8a1',
#  'df46cbb0-ed51-411f-8f39-15c43423abc5',
#  'c606611e-50b8-4141-b8f9-cea6b12a2db4',
#  '6ba2c2be-dd48-484c-bbef-f57dbd680bf0',
#  '629df17a-8d57-4c4e-99b1-d09b17afb446',
#  '924dfa5d-fc0f-416d-b19b-02ffe3acea1d',
#  'fb3bec8e-a94f-46c7-8692-7e349daa5bf3',
#  'a904a807-5854-464c-b2b1-270c06710af5',
#  'b70aaffc-787e-43a3-ac88-6747a611d88b',
#  '72269846-b2f3-48d0-9fb7-81c4b51034de',
#  'd94c168c-9677-4247-b59a-fd1d24b71b04',
#  'aaba8909-b973-43dd-b9a8-19d787c85511',
#  'bbe0039e-85d5-49bf-9d58-978a5c42eb0c',
#  '5a04c5fa-8536-49d0-b5dc-b611993f0daf',
#  '97324968-4942-45d6-8a4d-a7e12f2244c9',
#  '09e42a94-a421-4020-8bf9-9443c317b238',
#  '157430a8-d309-4d3b-8709-d2f7bffb9ecb',
#  '9a5f38e9-72dd-47d0-b271-5166bb7f435a',
#  '4805e46f-f736-4242-8035-eb4ef7e9d701',
#  '4371697b-28e1-4660-8164-ce03e3181596',
#  '86791434-67a4-4622-8f72-356ead90ba1b',
#  '9f47cf25-7fe0-410f-b8aa-b8da0a16b85b',
#  '6a3ea0ec-312f-4076-a956-df3238ea301e',
#  'cf071372-dc4b-4937-bfdd-0a662c1febb5',
#  'b6452ba7-879a-4111-9805-075a6eeac923',
#  '119f906b-3c1b-4b1c-8816-8c86e66fedf2',
#  '8f318f55-73e9-450b-b447-f64668b8586b',
#  '22b57162-7a5b-4552-b647-7fbc63c47e6f',
#  '9e4322aa-f82b-4243-9e03-d27f183a1211',
#  'c0eacfdb-fe3e-4434-9e2a-a8a921de44a7',
#  '12d9a1e2-932d-4af2-90c0-8c1d312c8282',
#  'c38672f8-5b95-45f4-aab2-09a999857cab',
#  '424e678b-4427-4b8d-86b0-5d3de9316ee7',
#  '42ad21c2-f938-413c-b1ed-8615bdc7fe31',
#  '65eca172-a739-433c-9ad9-dbd3bd1a1d0c',
#  'c3cb8f5f-b7e9-4db8-af64-9b0201ec69f7',
#  '79c224cc-9c97-4957-8f3a-533a30c97dd4',
#  '303e4e55-8410-43a9-9233-d2ea5c2c2ec3',
#  '5e824666-572e-4f32-a580-57987e772e06',
#  '545f65e8-ab5d-4a9b-91cc-e9725acedb91',
#  'a670d162-c182-4a37-af56-85a3448956b9',
#  '49cfaa9f-7c01-4e78-aebe-c83b9d7adb02',
#  'd22a1699-7737-4edc-9503-033ac9e74ae6',
#  'aacefa7e-3b8d-443c-9a99-90cfe8c5c1ff',
#  '9e39965d-c5d6-45f0-bb0d-a03d00cd0a05',
#  '4a4c0c14-ba29-4aae-9a13-5e1ddd3c575d',
#  '4f32530d-6c56-4e8f-9fe0-a3d270bf764a',
#  '34ee5557-c7bc-4f6c-aea4-b7b5506d4927',
#  '8fe141d6-923a-4f45-b94e-3685196c808f',
#  '4febc0d1-3024-43aa-bab1-6d21678cf797',
#  '386c7907-ac18-4a56-83cd-c3de4778ce65',
#  '03df5290-a307-475d-97fa-94461520b532',
#  'bd8cda10-3022-47ba-8050-c39a9ce61340',
#  '677b6c03-856e-45d7-90be-82bbaa8e9179',
#  '3738000f-8099-4b95-a89c-1ef9be465660',
#  'e551c8da-6423-4fa8-95be-43f96f4f3207',
#  '454414a6-5444-4431-b6f0-5c665dd08865',
#  '57b370e7-7c34-43f0-8424-b51c4565ce4c',
#  'f427ec8e-1688-402b-9d7c-38e1a72ceba7',
#  '1d0a7897-b114-4932-94a8-b1076ced82eb',
#  'c9b6382d-845b-40f8-ae94-58cdeb05eec8',
#  '960503db-e52d-46e1-b7d1-49a1b457a2c0',
#  '951c7c14-105d-4bf3-9bf0-23ebbce70820',
#  '4c901fcb-4243-4a30-b684-42b0790c4c95',
#  'bf12bb00-d79e-4903-aab3-5ed91c4f602a',
#  '4210e8b1-b3f5-4d2b-8eb0-fe02462e713b',
#  '1d2efd3b-43e2-4717-8464-edc8e29d87f2',
#  '5ed8e964-7c7d-457d-919f-db867d3382e1',
#  '08311e9d-f24d-47e2-84c7-e6b12f3addeb',
#  'd31eafae-9ed1-4e93-9387-8b227c645848',
#  'f6c1c158-8b36-49cd-bb18-ff37f58ffccb',
#  'fb3fef67-84a1-4959-994b-6edab2037e23',
#  '51811c1e-861c-45ab-a54d-ee45b39b3596',
#  '1f65a4e7-2bcd-41d8-835c-502d49748322',
#  '7f97806a-514c-4f83-8b16-2a46f0a168e1',
#  '197918e0-286b-4b7b-85c5-9db52bef052b',
#  'd3d9f226-8e43-4842-9bdb-9cdfca5b209f',
#  '9f655127-275d-44f2-aae6-75f34e8b1218',
#  '5dafcd07-bd0d-479c-8182-6d95129b3895',
#  '38f09f78-7f0b-455a-8885-574f1c87e104',
#  '5a70230b-2f11-4dd9-ba61-d23563e2178d',
#  '7ac5f493-d053-43a2-90df-8399b13ed458',
#  '4d5709e7-b9c7-4bb6-8d3d-2d275bd3a67d',
#  '7a782f01-6f7e-4be1-9787-3483e08f6693',
#  '32bad584-3538-4817-bcd0-ebcb06307957',
#  'd2964c4a-9834-4833-b6f8-bcc5ae601710',
#  '02112588-2b3b-4c5d-a93d-033635d3a21a',
#  'd31e96ad-f246-421c-8760-1cd3fd9a60c8',
#  'a7693709-c4e2-41fe-8f3e-aa04767d6d14',
#  '9fb21e7a-ff4a-4203-94a6-ff39815be89c',
#  'e681a6d5-aa3a-4864-8f12-2e24443cf1f0',
#  '8324e19d-4ea7-4e75-bc9d-142917b4f534',
#  '044f9a91-b77c-4d0a-bbca-3e56c0bc2101',
#  '8ec75e23-6d19-4b72-8872-39df295f7880',
#  'c1bbe05a-e25f-4ffb-b96e-c7e44a25d916',
#  '42f55e44-114e-44d2-b902-f5c2b505282f',
#  '1fbc2338-a4b0-42a6-af0a-c3b36816a601',
#  'fcaf84f4-389a-4cba-be8d-f5920189fc85',
#  '5fc2e69d-e987-48d8-a82b-774d6b6883f3',
#  'ef7de6f6-c92a-4b50-899c-3b52fdf803ff',
#  'ddb0f76f-33d8-4073-9472-a0381f1d6e4c',
#  '221436af-bede-4ac1-a50b-96a4864a74dc',
#  '56b6a9a9-a0f8-427b-b748-5b2c0adea81b',
#  '121b1387-5636-4954-859a-f34119fa54ba',
#  '54384b4d-b7a5-4182-8a48-507773cdfe5e',
#  'e4d78fa0-247a-4775-9410-70a4802f7033',
#  'ca1e623a-88e5-4327-9934-7bf4af766b7e']

# %%
# looking how the data looks in the db

vector_store.get(include=['embeddings','documents','metadatas'])
# Out:
# {'ids': ['77d95c03-2428-48b8-9f8a-7cb38710019e',
#   'a68ea041-41b6-4067-806b-7006031c63d0',
#   '3d1d10fe-7861-40cb-a235-590225177cf2',
#   '46619b21-1275-4849-8b9e-987c864e7080',
#   '9ab4734b-15bd-40bf-8c63-2206faffe1ca',
#   '68371767-6ee7-439b-88b6-9c3a862b9371',
#   'bd0e0df2-f1ee-42c9-ba34-fe8cc60b150e',
#   '8dcebd81-9cb5-4c80-bdcc-6817ec7b3902',
#   '7bb82ef3-4489-4ebb-8f5c-013f948910dd',
#   'df51725d-7c79-400e-a460-e13075be9907',
#   '743b6fd9-9c75-4b50-bcf4-7a9322eeeac5',
#   'e1ab6feb-489e-4419-9150-ab72b79a51eb',
#   '0d94299b-8169-4299-8c1f-2d90ba94c529',
#   'e81cc53e-9866-4624-8d01-e65dc6e56211',
#   '3fac0c6a-3585-4af4-b837-94b1afc5d585',
#   '35fbaf65-6561-4e9c-9a89-213aeeda783a',
#   '6b4a076a-234a-4ddf-b4a5-95bdcf79dd23',
#   '8b138ecd-701d-4deb-91f6-fae6f0a45c54',
#   '5d5b0bc6-eb70-47ca-ba8b-832906fd2781',
#   'c8eef204-3e38-4d93-bc23-097b3daecc39',
#   '2b5fab67-5bbc-414b-a4bf-c856f4273ebc',
#   'fcdff695-aaa5-4ee4-9ae3-e23345c4abd0',
#   'fe79486b-8966-4eb5-a9cc-1a87eeab630a',
#   '79a4e224-9ada-4c62-be5a-3eacba5b9639',
#   '4c56ad74-4522-49e0-a7af-d8f85960ff04',
#   '595b1a01-b2b1-4b6d-a4f6-ec457482e57a',
#   '01f57ff2-bde0-4bd3-92c9-f62d9fe75a3d',
#   '1ecd25b7-ef84-481b-8098-4f9f57fd6ad7',
#   '8481bfd5-316c-4ead-acce-40f110e32b36',
#   '49c29ad2-a9f3-4548-bfeb-c722411b4de2',
#   'da25b48d-16b1-46f0-9280-33b2128b4f63',
#   'bc436dc9-08f7-43fd-a23a-f0804487e291',
#   '2b4aff88-d61c-464e-a72e-bc60ce5a0155',
#   '61ff3107-fa4f-465e-914b-4565066a1219',
#   '5aabf27c-f2b7-4a1f-acfb-426bd5bb056d',
#   '6858c145-ba0f-4f67-b700-1451b2236d34',
#   'ff9fe7e4-0f8b-4b69-a953-41cb5c6fa358',
#   '35f05ec4-6042-44b4-a297-d7d3805c57b8',
#   '4ccbdb2c-0758-43da-bf8c-6737919fd7a5',
#   '1d210583-82e4-40d9-b96b-4f5ffdbce01d',
#   '7911defc-6d7c-4eac-bb19-bb1607cecbd8',
#   'b5e7cf30-e415-40e7-8ada-8ed572da7f6f',
#   'b1f2ecf2-4330-4f54-948f-4992ad60ceae',
#   '4195a36a-f917-4b6c-a0a8-24eb207a160f',
#   '33dc5dd5-b10f-410f-a1b8-bd80775befb1',
#   '3224491d-0eb3-4294-9d39-480e28a987ed',
#   'dce3a14a-2edc-4156-b448-84e909fa5f97',
#   'a138ed5e-3499-4f01-81e7-8c17768e6681',
#   '5a176a21-ce64-45d5-ac27-0faa9244119e',
#   '9e3c0cd5-3a7c-4684-8a85-fcf6f090c892',
#   '7ecdd52e-2e51-4c23-b84b-679077502495',
#   'fb819501-d200-4b18-908d-fe2e807abb8c',
#   'eb0cc777-666a-442a-893a-3539f1ff0509',
#   '5b85968c-1af2-46c3-bf92-a5cd3d673c60',
#   '78a5850b-a3e3-442f-83be-1c637f7df6cb',
#   '4845a4d6-1915-41e5-82f9-7f88129d40ec',
#   '778a84e7-ba9e-4b3e-9114-c8d403a2f9d5',
#   '3782ff2c-4389-41e5-a37f-f166fd033586',
#   '4dedd623-a631-44d6-94a5-9d6dbb191ebb',
#   '08040b57-90b2-4128-9b56-b125ad71d691',
#   '44c8f948-5034-40bf-9259-5d3cfb2b84d7',
#   'a271487c-d535-49a3-96eb-560fd6ce7165',
#   'ed918ab2-5b5c-4158-b88c-a5532c975528',
#   '7da49ac0-4723-4b61-a38b-2324a869c0be',
#   '32d03ff8-0f3c-4021-9e03-f468256dc3b1',
#   '3adefce0-36a8-4d5c-9329-17a52fc18684',
#   'cbfffc4b-03fb-4d06-b192-d380e8d4bb13',
#   'a4ccb1c0-da66-442f-abb3-c4b62c16487c',
#   'b7c415c5-c657-40b4-9500-d567e4846ca2',
#   '37212e2a-914f-42ff-ae83-f10bd69cc275',
#   'a19b7cd7-da6b-4ff9-a3b4-2fb36197a440',
#   '2c984f26-91d3-4c58-b51d-f4ae3b74cc4f',
#   '74a6b80a-bb0f-4345-b617-4bb4183f209a',
#   '63a6db26-c0ad-4ecd-abb0-ea247be30761',
#   'fc74d8c6-4a18-4007-8139-7222b10616e9',
#   'cd08429e-869c-42b4-87e0-70b43fe7c59f',
#   '7e413480-873f-474b-8e6d-4a3c9e519a64',
#   '11e085cd-6ac6-40d5-9787-4883173a5276',
#   '63284745-4aae-4cc6-a0a4-9898fe9e7dab',
#   'b89a0551-77a9-4ba9-9411-e92f05748eff',
#   '12e9ee8d-0b73-413f-bafe-6acc2df254ed',
#   '9c0c67be-4ad6-4ca1-9050-40e0b7ecf6c5',
#   'bf43de09-26e6-4b36-b39a-b16c29a25027',
#   'afddf46c-e4a8-446a-bb89-2f39b6487d74',
#   '59d5e485-8f89-4246-bd0a-150515a0ae51',
#   '477939bc-99a8-429e-9d6d-8d4236e13a42',
#   'bb5d9a0b-3600-4c52-b6f9-366072af6764',
#   '75d3dc47-af34-4b68-b92f-65577aed67fd',
#   '1f441288-f871-452a-8b84-9f621f8fbd8d',
#   '90bc1bf0-7aac-4d46-b758-f9584f633a91',
#   '07c1df5d-c41a-4c4f-998f-e42ad63fdbd2',
#   'acfe2575-cb10-4bcc-8811-54290a4fcb4e',
#   'a04f5fa7-8433-42fc-ae95-a8e0d402ccbc',
#   'e9409a85-867c-439c-8b12-f9513556e97a',
#   '508e72a1-e847-42e3-954b-2c3afae13a08',
#   '2cfe2402-2664-460e-8cb0-d51cfaaf8b97',
#   '5bcde254-b003-41ce-8351-1be06bfd1806',
#   '1f0db402-4123-4b2d-b57c-3ddadbf84972',
#   '4f23618e-acee-4594-93a6-a9e00bae6f5b',
#   '0dc98efc-9b29-4d4f-b332-43b26b2b02dd',
#   'b312b49a-790a-4c88-bf78-f3a467efbff1',
#   '5469b023-5726-4daf-8897-106ed47055dd',
#   'f389cfc2-2fb3-4884-ac08-ac6e166929df',
#   '150173e3-9a43-48e5-b99a-72a941b825a0',
#   'a380363d-8383-4443-99b5-b86321afa0ad',
#   'c00dea64-04bf-40ac-b516-592c10846455',
#   'ec757299-0428-4cad-bb4b-874cb5ec254d',
#   '3053ae5f-f7d7-4896-96d2-20f319e059de',
#   'ce3985ee-139e-491c-bde5-736618630819',
#   '120ecba9-e230-4d18-943b-de540ed6a9ae',
#   '7d91719c-9930-43f1-a13a-13979779d1ef',
#   'bec885d5-e406-46f9-be12-fe8625409deb',
#   '8da2fb50-2d57-4307-bfb3-ef5913a58b1f',
#   'a27fe1ac-63b9-4dab-b8ad-50f3cb9df609',
#   'a563d193-788a-4eca-8c92-3e5fe090eede',
#   '1f663bc9-3af3-4002-8205-f859883a2c2c',
#   '92744e23-724a-4cec-bd4e-75ebe86fd074',
#   '8e3925ab-1486-49c4-80e6-5534e5ef9640',
#   '4a4af489-0683-4140-bfbc-62d76bb6cd84',
#   '6360b534-c938-43b4-90d4-86e6e8830c6a',
#   '124305f5-8e94-427d-bc6d-95bbd52c62d6',
#   'ad5b819c-5ef0-43d1-8e02-8944530d5fa5',
#   'ed02507c-765e-4d80-a56b-97b04dba0a23',
#   '14e4a301-8aff-4c26-81fb-b607c94a07bf',
#   'dc2b5ea2-d520-4da4-98cf-f690dbe64c7b',
#   '8ec5503d-133b-45e0-83ce-9d9694132655',
#   'f7616452-c051-4113-a911-6597acaba95a',
#   'f2ec3868-eb65-4278-afe3-f93b3b05f696',
#   '9776a71f-124f-4e16-b66d-52d821d0e173',
#   'a79c07bd-85f1-4dd5-ba3f-bfac76258f17',
#   'a14eca47-c77e-4a90-87a6-693f1ed9fdfb',
#   '9773dcfc-fa66-4756-a308-f03f7497f11e',
#   '95f50d98-9009-4d20-b4ab-9d22434da4c5',
#   '7888a897-f267-491b-a87d-07847d0ff6c2',
#   '139ab0aa-c2b8-4adb-bf8f-6d7c112ebea4',
#   '172652a9-1ba5-4855-bb89-3b0c543a2149',
#   '4939e331-511e-4cd0-986d-ce4581c21e8a',
#   '8c79e799-b641-4c5e-be58-3ab3ef4af766',
#   '3f75ec80-b249-4039-9ad8-2f7d1d18bede',
#   '05f5899f-11ec-4eac-b298-51507a8f053b',
#   'f3ea8dd0-d8df-4c13-b2be-e9c896258e42',
#   'e027453c-d1c1-45f1-a583-ad197fe0b6b9',
#   '2e394bea-21f1-4428-8c64-e5affbf0dfd5',
#   '6e17eb78-6626-4e28-acb5-0490be4fb1ae',
#   '1277f95b-fd74-46aa-8fab-60d96eff1f18',
#   'c7c87f0e-fa95-40af-abfb-122fe42026f9',
#   '0f6da4ba-24c3-46a7-a6fb-a3f05fa91920',
#   '4bfd80a2-4f7b-49e9-9faa-a24a717637d5',
#   '283e035e-d18e-4b38-b35a-df8bc2622cd7',
#   '12e31772-7a02-4388-aa01-856d2cdab22f',
#   'aa1811f5-c908-48d5-b981-6cd073af4e3c',
#   '7b0ad667-1046-4e4b-9212-08997186283e',
#   '98333ed5-a32e-42bf-a84e-098d4690310d',
#   '53f7e531-fd92-4803-9724-2db4e684fcfb',
#   '938cf263-62cb-49a4-bfa7-d97fb5d70f9f',
#   '3a389dc0-5779-489e-8a57-cd5b9103d565',
#   '22942a0d-62d5-4ae4-b79e-dbd628d41a41',
#   '3d376b0c-8487-445e-ad48-d2453e04dd47',
#   'e200b8f6-44c5-4bf4-9875-1ab9447c07ff',
#   '2db4d1ff-a60c-49c7-b667-03f601d1c928',
#   'f477709b-6356-479e-8fbf-5c7f5d472316',
#   '15bb556c-e753-42d7-8c36-441eabd8f60b',
#   '8386d211-2cc2-4cb0-bc71-08bc8ec914f8',
#   '029c53d4-fe82-4812-a4a3-b631a3922d86',
#   'c8d63f59-40f2-4de3-90aa-dc9438c2d65d',
#   '7bb33e84-c91d-456d-8406-5b3fc8ebca85',
#   '20381372-c2bc-4df3-b4c6-fbc4cc6bfee5',
#   'da23852f-ec48-4eda-94ab-e9c84ea50fab',
#   'bf899a80-e235-444c-aecb-0b620095a64f',
#   '5dd13de1-5fa0-4474-ac8c-7368a19d0f8c',
#   'f9b23cad-7c5f-4084-8323-14c961cb2347',
#   '46ec03f4-6b05-443f-9552-eefd2d867c56',
#   '6a86edfc-5288-49e9-8087-56a4cc06906f',
#   '20ef1b41-44d6-423d-b21a-4ca346d08ea1',
#   'ec6ab86b-08f9-42fd-b2c8-d3d9def54b27',
#   '10134743-c94d-4316-b78d-6a4ede58bfe0',
#   'd86f9a77-7878-466b-bf75-943e55c0aa22',
#   '316d44cc-0fb1-48ac-bf93-75e509dc80fe',
#   '65473940-5a1e-4c32-9e7d-a07939cb25fa',
#   '8d238b06-4637-4e2a-9054-88c160eefca0',
#   '76d4842f-473a-49f9-8866-6c97ac1b3308',
#   '404b53f7-f4b0-4d76-9371-de363f64a5d9',
#   '38abaf3b-e95a-4cb3-ada8-00fd205dcf2e',
#   'be39a790-dfb2-4f72-9eec-81edbf25e773',
#   '61acbe7c-017a-44b3-96aa-c99387d5439d',
#   '6474d13c-1a52-46d8-a250-e559fd6300c8',
#   'e097a478-bc9a-4d14-aad1-e7493a17c646',
#   'f19876b4-2393-4975-93c5-42859a788f8b',
#   'f488e90b-49db-4048-88b4-1de90910794e',
#   '71fc1bbc-7bae-4db5-b097-d9f933cef5ed',
#   '10c99b33-b01f-4f2f-9ef1-3ec8e1a1574d',
#   '94b99edc-a73b-45c5-a0de-12f46547297f',
#   'ad501abe-084d-4354-b072-a890f25e0e58',
#   '0ed4f087-1f15-46e9-9cd8-03b764f37df1',
#   'adc4ef38-e735-4484-bc6d-8ca6f00c1d99',
#   'e123bb82-d5a5-4a77-b3d2-2dbaadd6661d',
#   'e0eb0efa-21a8-4ef2-ac45-49319bfcb5fb',
#   'b34bd359-a8f4-4ee7-a3f6-e4f3178053fd',
#   'ff097d2e-8005-47ea-bc49-eb5894e998c7',
#   '3b595b2b-f4e3-4e97-9a02-dd0636489972',
#   'ae628234-a576-4c6c-a454-5c921224228b',
#   'e5b41aea-80b7-474b-ae85-9413e69be775',
#   '0a918a8a-da1f-48c3-9383-022d17ca41b5',
#   'c2f5a0a1-6046-48c7-931e-244ea1425d4a',
#   'a55de50d-67d5-4649-9834-a045b428d615',
#   'a8c6fc10-cc06-4ee8-8c8b-c70a342dbafe',
#   '1976ea90-0cc0-49ad-8dfd-66646607f96a',
#   '5eeeb35b-3a96-431c-a9ff-0088233fbe8e',
#   '35de4336-198a-4d30-b013-f01cbc129691',
#   '071a17e6-2e1a-40c4-88af-1c39151df74a',
#   'c596be3f-b047-4500-8d61-2c203cf93721',
#   '33d232f8-2cb6-46e3-87b8-f42a33a86b56',
#   'a590ebf7-61ae-44cc-b882-22eea4f89bb0',
#   '3491c91d-ce61-4894-b7b9-67040286f42e',
#   '1eac6f32-2d8a-4cd1-ab3a-3083b27c268a',
#   '00ddf7cd-8b5b-4e0d-ba0c-30e702475670',
#   'a51d0948-883f-4e72-86ff-1397ca45a412',
#   'ca72af2a-2238-403d-aae9-c2081932e15a',
#   '730a4dc0-82bf-44b9-897d-0ba30f3be188',
#   '6e85ef12-7857-45d7-a505-a516111f6f93',
#   '309a237f-68e8-4fb8-a1d8-0811c75ce2dd',
#   '625ea9e8-51d6-479b-8aa0-6849dc8634de',
#   'c5bfaa60-3854-4026-8ac6-324a7193c492',
#   '8a57be10-eb80-4d3f-871f-3eb22e34e761',
#   '0977128d-6e4b-4ae7-a13e-fac6b1199e4e',
#   '10048c3e-3692-46c8-8c28-7c88a3f8fb9a',
#   '88de30fe-a899-4262-b5aa-2e48ba18f474',
#   '5fbbd0bd-3cbf-4186-afaa-efd24e261f13',
#   '6f7e74cd-9bde-4c5b-8157-5f38f12e7c56',
#   '0c16131f-cc16-4bd7-b263-f4b58a6b5329',
#   'a4594418-b88c-43f4-8607-843974acd82e',
#   '54cc48bf-d77e-4cc0-bf5e-9cf9aeaf4e41',
#   'af2590f2-8f52-4b66-b238-4354de531217',
#   '92213614-22bb-47ef-ba02-31ae6e5b6ff9',
#   'f3bf4275-09b6-4670-8e98-72481a6e70d6',
#   '12f0286e-e471-4146-bf3c-da374c593ab9',
#   'c5ddfac6-f243-4961-b7d1-74bc5aa7844e',
#   '52561e08-ea60-4f60-a4af-3f50495cad0e',
#   '6a16b71f-afce-45cd-9ab9-3049a9ffb997',
#   '5963ded3-c770-48b3-bd41-b9c1ee7b2743',
#   'e8537838-3ca9-4425-b79f-39bce7a65dcc',
#   '2c0edf24-24a4-4bc1-9445-861292ad7e98',
#   'f65de4e4-fa68-46a2-a4de-da800318be64',
#   '782fd5db-b7a1-4463-b4e0-f9517a3ee161',
#   'e845a8a0-312f-430a-bb63-4b6860f7670b',
#   '6be91ddf-b37a-48af-ab3a-da75a5cb78c8',
#   'eb15b9ce-5aa1-4147-9913-d891ac55e8b2',
#   '8d3f27ec-d2e2-48ba-9483-382e67ceb3eb',
#   '7a5175ed-28b0-4ad0-a1e9-1f07cc678da2',
#   'e9e14d79-3b2d-4bd7-b0fa-5136303fc09e',
#   'ff1c04d5-f340-42e8-922b-164feedbe056',
#   '3c31cd4a-d998-4f63-8821-0198dc66a523',
#   '92dcaa38-0343-4169-bf80-406fd5ba341e',
#   '2033d6a9-96af-4639-880f-e20d1bce5290',
#   '08d248a3-d22b-4edb-862b-99e8ce83b5af',
#   'f10bb92b-fe84-4316-a261-4dfb5c530817',
#   '2cb4b811-9f0e-40b0-a1c6-6e89c7d8565d',
#   'b7a0280a-7dda-451d-b6fe-2379763d1fe4',
#   '87ba3ae9-1ccc-458c-af22-9efc505c373a',
#   '968cf8a6-847c-492c-b031-447cb4c9f547',
#   '047f94c6-518a-4d4b-ad3b-f3280b55c5b7',
#   'b9467859-82c2-4790-a67e-0e564891d19e',
#   '89caffe9-e42f-487c-8f49-c72c80861497',
#   '71e757b6-58a8-468b-8571-82f0f996a318',
#   '0fbbba82-b6ae-4c7b-99a0-2220a92752f2',
#   '8e301965-9af1-4a34-a692-fa9e112d19a4',
#   '2bfcac1b-b56e-4711-be0c-0d3efa57a315',
#   'b355820f-0407-4d90-9a60-8195a0474267',
#   '9403588a-617a-47a4-bf5d-10f9258ae58c',
#   'fb016668-734f-4edb-a16c-6562bf73e83d',
#   '81db6a9c-58b0-40a7-ad9c-f86089c26398',
#   '97e9c560-8a76-40c2-9a42-68adde53321b',
#   '313f7f0a-0bed-4f3d-a132-9b3c01c9f8a1',
#   'df46cbb0-ed51-411f-8f39-15c43423abc5',
#   'c606611e-50b8-4141-b8f9-cea6b12a2db4',
#   '6ba2c2be-dd48-484c-bbef-f57dbd680bf0',
#   '629df17a-8d57-4c4e-99b1-d09b17afb446',
#   '924dfa5d-fc0f-416d-b19b-02ffe3acea1d',
#   'fb3bec8e-a94f-46c7-8692-7e349daa5bf3',
#   'a904a807-5854-464c-b2b1-270c06710af5',
#   'b70aaffc-787e-43a3-ac88-6747a611d88b',
#   '72269846-b2f3-48d0-9fb7-81c4b51034de',
#   'd94c168c-9677-4247-b59a-fd1d24b71b04',
#   'aaba8909-b973-43dd-b9a8-19d787c85511',
#   'bbe0039e-85d5-49bf-9d58-978a5c42eb0c',
#   '5a04c5fa-8536-49d0-b5dc-b611993f0daf',
#   '97324968-4942-45d6-8a4d-a7e12f2244c9',
#   '09e42a94-a421-4020-8bf9-9443c317b238',
#   '157430a8-d309-4d3b-8709-d2f7bffb9ecb',
#   '9a5f38e9-72dd-47d0-b271-5166bb7f435a',
#   '4805e46f-f736-4242-8035-eb4ef7e9d701',
#   '4371697b-28e1-4660-8164-ce03e3181596',
#   '86791434-67a4-4622-8f72-356ead90ba1b',
#   '9f47cf25-7fe0-410f-b8aa-b8da0a16b85b',
#   '6a3ea0ec-312f-4076-a956-df3238ea301e',
#   'cf071372-dc4b-4937-bfdd-0a662c1febb5',
#   'b6452ba7-879a-4111-9805-075a6eeac923',
#   '119f906b-3c1b-4b1c-8816-8c86e66fedf2',
#   '8f318f55-73e9-450b-b447-f64668b8586b',
#   '22b57162-7a5b-4552-b647-7fbc63c47e6f',
#   '9e4322aa-f82b-4243-9e03-d27f183a1211',
#   'c0eacfdb-fe3e-4434-9e2a-a8a921de44a7',
#   '12d9a1e2-932d-4af2-90c0-8c1d312c8282',
#   'c38672f8-5b95-45f4-aab2-09a999857cab',
#   '424e678b-4427-4b8d-86b0-5d3de9316ee7',
#   '42ad21c2-f938-413c-b1ed-8615bdc7fe31',
#   '65eca172-a739-433c-9ad9-dbd3bd1a1d0c',
#   'c3cb8f5f-b7e9-4db8-af64-9b0201ec69f7',
#   '79c224cc-9c97-4957-8f3a-533a30c97dd4',
#   '303e4e55-8410-43a9-9233-d2ea5c2c2ec3',
#   '5e824666-572e-4f32-a580-57987e772e06',
#   '545f65e8-ab5d-4a9b-91cc-e9725acedb91',
#   'a670d162-c182-4a37-af56-85a3448956b9',
#   '49cfaa9f-7c01-4e78-aebe-c83b9d7adb02',
#   'd22a1699-7737-4edc-9503-033ac9e74ae6',
#   'aacefa7e-3b8d-443c-9a99-90cfe8c5c1ff',
#   '9e39965d-c5d6-45f0-bb0d-a03d00cd0a05',
#   '4a4c0c14-ba29-4aae-9a13-5e1ddd3c575d',
#   '4f32530d-6c56-4e8f-9fe0-a3d270bf764a',
#   '34ee5557-c7bc-4f6c-aea4-b7b5506d4927',
#   '8fe141d6-923a-4f45-b94e-3685196c808f',
#   '4febc0d1-3024-43aa-bab1-6d21678cf797',
#   '386c7907-ac18-4a56-83cd-c3de4778ce65',
#   '03df5290-a307-475d-97fa-94461520b532',
#   'bd8cda10-3022-47ba-8050-c39a9ce61340',
#   '677b6c03-856e-45d7-90be-82bbaa8e9179',
#   '3738000f-8099-4b95-a89c-1ef9be465660',
#   'e551c8da-6423-4fa8-95be-43f96f4f3207',
#   '454414a6-5444-4431-b6f0-5c665dd08865',
#   '57b370e7-7c34-43f0-8424-b51c4565ce4c',
#   'f427ec8e-1688-402b-9d7c-38e1a72ceba7',
#   '1d0a7897-b114-4932-94a8-b1076ced82eb',
#   'c9b6382d-845b-40f8-ae94-58cdeb05eec8',
#   '960503db-e52d-46e1-b7d1-49a1b457a2c0',
#   '951c7c14-105d-4bf3-9bf0-23ebbce70820',
#   '4c901fcb-4243-4a30-b684-42b0790c4c95',
#   'bf12bb00-d79e-4903-aab3-5ed91c4f602a',
#   '4210e8b1-b3f5-4d2b-8eb0-fe02462e713b',
#   '1d2efd3b-43e2-4717-8464-edc8e29d87f2',
#   '5ed8e964-7c7d-457d-919f-db867d3382e1',
#   '08311e9d-f24d-47e2-84c7-e6b12f3addeb',
#   'd31eafae-9ed1-4e93-9387-8b227c645848',
#   'f6c1c158-8b36-49cd-bb18-ff37f58ffccb',
#   'fb3fef67-84a1-4959-994b-6edab2037e23',
#   '51811c1e-861c-45ab-a54d-ee45b39b3596',
#   '1f65a4e7-2bcd-41d8-835c-502d49748322',
#   '7f97806a-514c-4f83-8b16-2a46f0a168e1',
#   '197918e0-286b-4b7b-85c5-9db52bef052b',
#   'd3d9f226-8e43-4842-9bdb-9cdfca5b209f',
#   '9f655127-275d-44f2-aae6-75f34e8b1218',
#   '5dafcd07-bd0d-479c-8182-6d95129b3895',
#   '38f09f78-7f0b-455a-8885-574f1c87e104',
#   '5a70230b-2f11-4dd9-ba61-d23563e2178d',
#   '7ac5f493-d053-43a2-90df-8399b13ed458',
#   '4d5709e7-b9c7-4bb6-8d3d-2d275bd3a67d',
#   '7a782f01-6f7e-4be1-9787-3483e08f6693',
#   '32bad584-3538-4817-bcd0-ebcb06307957',
#   'd2964c4a-9834-4833-b6f8-bcc5ae601710',
#   '02112588-2b3b-4c5d-a93d-033635d3a21a',
#   'd31e96ad-f246-421c-8760-1cd3fd9a60c8',
#   'a7693709-c4e2-41fe-8f3e-aa04767d6d14',
#   '9fb21e7a-ff4a-4203-94a6-ff39815be89c',
#   'e681a6d5-aa3a-4864-8f12-2e24443cf1f0',
#   '8324e19d-4ea7-4e75-bc9d-142917b4f534',
#   '044f9a91-b77c-4d0a-bbca-3e56c0bc2101',
#   '8ec75e23-6d19-4b72-8872-39df295f7880',
#   'c1bbe05a-e25f-4ffb-b96e-c7e44a25d916',
#   '42f55e44-114e-44d2-b902-f5c2b505282f',
#   '1fbc2338-a4b0-42a6-af0a-c3b36816a601',
#   'fcaf84f4-389a-4cba-be8d-f5920189fc85',
#   '5fc2e69d-e987-48d8-a82b-774d6b6883f3',
#   'ef7de6f6-c92a-4b50-899c-3b52fdf803ff',
#   'ddb0f76f-33d8-4073-9472-a0381f1d6e4c',
#   '221436af-bede-4ac1-a50b-96a4864a74dc',
#   '56b6a9a9-a0f8-427b-b748-5b2c0adea81b',
#   '121b1387-5636-4954-859a-f34119fa54ba',
#   '54384b4d-b7a5-4182-8a48-507773cdfe5e',
#   'e4d78fa0-247a-4775-9410-70a4802f7033',
#   'ca1e623a-88e5-4327-9934-7bf4af766b7e'],
#  'embeddings': array([[-0.10029397,  0.06751103,  0.02810422, ..., -0.05964583,
#          -0.00295316,  0.00119498],
#         [-0.07417461,  0.01700752, -0.02943341, ..., -0.069388  ,
#           0.06838048,  0.02391044],
#         [-0.04793886,  0.13652766, -0.06925739, ..., -0.05345685,
#          -0.04134865,  0.00976358],
#         ...,
#         [-0.01737777,  0.08927481,  0.06519867, ...,  0.035061  ,
#          -0.03208086,  0.0429154 ],
#         [-0.06061546,  0.00597804,  0.02994096, ..., -0.00764644,
#           0.07562663,  0.07257482],
#         [-0.01308706,  0.11785393,  0.00307844, ..., -0.03349728,
#           0.01229835,  0.03742924]], shape=(379, 384)),
#  'documents': ['13 V May 2025\nhttps://doi.org/10.22214/ijraset.2025.70977',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3461',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   'Prepmania: an AI-Powered Mock Interview \nPlatform for Skill Evaluation and Performance \nFeedback',
#   'Feedback',
#   'Siddhi Awasare 1, Shreya Vedpathak 2, Shravani Pawar 3, Sanika Hatrote4, Sakshi Patil5, Mrs. K.A.',
#   'Mrs. K.A. Bhosale6',
#   '1,2,3,4,5Students, 6Assistant Professor ,Computer Science & Engineering, D Y Patil College of',
#   'of Engineering & Technology, Kolhapur,',
#   'Maharashtra, India',
#   'Abstract: Prepmania is an AI -powered mock interview platform designed to help job seekers prepare',
#   'prepare effectively for real',
#   'interviews. The name combines "Preparation" and "Mania," reflecting a passionate, focused approach',
#   'approach t o interview readiness.',
#   'The system generates role -specific questions based on user inputs like job title, skills, and e',
#   'and e xperience. A key innovation is its',
#   'multimodal analysis— using facial expression recognition and voice analysis to assess confidence,',
#   'communication, and behavior.',
#   'Prepmania enhances preparation through AI -powered feedback, response comparison, and visual per',
#   'per formance analytics. It',
#   'simulates real interviews with timed questions and tracks progress across sessions. Built with',
#   'with Next. js, it uses Clerk for',
#   'authentication, Drizzle ORM for database handling, Tailwind CSS for UI, and Neon as its cloud',
#   'its cloud database.',
#   'Keywords: AI mock interview, Gemini API,  Video analysis, job specific questions, evaluation.',
#   'I. INTRODUCTION',
#   'Proposed an AI -based mock interview behavioral recognition system that simulates real -time',
#   '-time interview scenarios using a virtual',
#   'recruiter. The system captures and analyzes multimodal inputs such as facial expressions, speech',
#   'speech patterns, and emotional  responses',
#   'to assess a candidate’s performance. It integrates machine learning models for emotion detection,',
#   'pe rsonality recognition, an d',
#   'sentiment analysis, providing users with detailed feedback and progress tracking across sessions.',
#   'sessions. Their work highlights the potential',
#   'of AI in improving interview preparedness by offering objective, data -driven insights into',
#   'into behavioral traits. This research lays the',
#   'groundwork for implementing intelligent virtual coaching systems in career readiness tools.  [1].',
#   '[1]. Prepmania advances this further',
#   'through the integration of computer vision and speech processing algorithms to evaluate user',
#   'user perform ance accurately. Other',
#   'research has examined the effectiveness of dynamic, chatbot -driven mock interviews that adapt',
#   "adapt depending on the user's response",
#   "and track their performance over time — a function that informed Prepmania's personalized question",
#   'question generation and real -time',
#   'performance-monitoring functionality [2]. The platform leverages natural language processing (NLP)',
#   '(NLP) and machine learning',
#   'algorithms to analyze both verbal and non -verbal responses in real time. Key features include',
#   'include context -specific question generation,',
#   'speech recognition, sentiment analysis, and performance scoring. The system provides immediate',
#   'immediate feedback on various aspects  such',
#   'as communication skills, confidence, body language, and technical knowledge. By offering',
#   'offering personalize d and scalable support, t his',
#   'AI-powered solution serves as an innovative tool in career development and recruitment preparation.',
#   '[3].',
#   "Interview preparation is an essential part of job acquisition, especially in today's competitive",
#   'job  market. Traditional prep aration',
#   'techniques, such as mock interviews wit h peers or mentors, are subjective in feedback,',
#   'feedback, intermittent, and not comprehensive in',
#   'assessment. These practices are most likely to yield little behavioral information, and it is',
#   'and it is diffic ult for candidates to tra ck their real',
#   'progress.',
#   'To address these sho rtcomings, we present Prepmania — a computer -based mock interview platform,',
#   'platform, built using Next.js and a',
#   'modern web stack. The platform delivers role -specific, user-profile-based interview questions and',
#   'and evaluates verbal and non -verbal',
#   'cues through multimodal an alysis, including body language, tone, and speech intelligibility. These',
#   'These behavioral signals help del iver',
#   'objective, real-time feedback to candidates, enabling them to identify improvement areas and',
#   'areas and enhance their interview readiness.',
#   'Prepmania does this by using a very detailed feedback dashboard that compares user responses with',
#   'with the best responses generated by',
#   'AI and displays progress in graphs and reports. This paper captures the system design, development',
#   'p rocess, and initial user',
#   'response for Prepmania. The findings set the potential of AI and web technologies to transform the',
#   'the interview preparation pro cess to',
#   'make it more streamlined, personalized, and evidence-based.',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3462',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   'II. RELATED WORK',
#   'Previous studies in the area of intelligent hiring technologies have shown promising outcomes in',
#   'in the  use of video and behavio ral',
#   'analytics to extend the assessment of candidates.',
#   'Contemporary software like HireVue and MyInterview employs AI -driven video t ests to examine the',
#   'the facial expressions, tone of',
#   'voice, and speech of candidates. Such systems, however, are mainly developed for assessment from',
#   "from the  recruiter's perspective and",
#   'do not focus much on learning and monitoring development of candidates.',
#   'Conversely, Prepmania is user -oriented as it aims to improve interview preparation by means of an',
#   'of an interactive online experience.',
#   'Through our site, we incorporate body posture analysis, voice measurement, and computer -mediated',
#   '-mediated response analysis for the',
#   'purposes of mimicking actual interview settings and providing constructive criticism to the user in',
#   'user in real time.',
#   'The research "Efficacy and Benefits of Virtual Mock Interviews: Analyzing Student Perceptions of',
#   'of Dig ital Employment',
#   'Preparations" by Indiana University of P ennsylvania\'s LeAnn Wilkie and Joseph Rosendale  [19]',
#   '[19] identifies the requirement of',
#   'replicating real interview procedures while providing complete, personalized critiques on nonverbal',
#   'nonverbal communication, response',
#   "timing, and content value. This outlook is consistent with Prepmania's aim to exactly replicate",
#   'replicate real interview situations and provide',
#   'constructive feedback.',
#   'Similarly, the research paper "AI -Based Mock-Interview Behavioral Recognition Analyst" by Kolpe,',
#   'by Kolpe, Patil, Deshmukh, Jeughale,',
#   'and Misal emphasizes the  need for artificial intelligence systems that can accurately decipher',
#   'decipher nonverbal behavior, support va ried',
#   'interview styles, and offer end -to-end performance analysis [1]. Prepmania follows these',
#   'these recommendations by using AI models to',
#   'examine physical behavior and communication effectiveness in real time.',
#   'The paper titled "Conversate: Supporting Reflective Learning in Interview Practice Through',
#   'Through Interacti ve Simulation and Dialogi c',
#   'Feedback" by Taufiq Daryanto et al. (2024)  [18] presents a next-generation AI-driven interview',
#   'interview simulation tool aimed at fostering',
#   'reflective learning among users preparing for job interviews. Conversate utilizes state -of-the-art',
#   'Large Language Models (LLMs )',
#   'such as GPT-3.5 and GPT-4 to not only simulate realistic interview conversations but also support',
#   'support learners in reviewing, analyzing,',
#   'and improving their answers iteratively.',
#   'This research by P. K. Mishra, A. K. Arulappan, I. -H. Ra, T. M. L, G. R. G and Y. -S. Lee,',
#   '-S. Lee, "AI-Driven Virtual Mock Interview',
#   'Development," 2024 Joint 13th Inter national Conference on Soft Computing and Intelligent Systems',
#   'Systems and 25th International',
#   'Symposium on Advanced Intelligent Systems (SCIS&ISIS), Himeji, Japan, 2024, pp. 1-4, doi:',
#   '10.1109/SCISISIS61014.2024.10760210 [16] contributes to the field by demonstrating the potential of',
#   'of AI in creating adaptive',
#   'learning environments, particularly in the context of professional skill development. The virtual',
#   'virtual mo ck interview system serves as a',
#   'tool for users to engage in self -paced, reflective practice, ultimate ly aiming to boost',
#   'to boost confidence and competence in real -world',
#   'interview settings.',
#   'Shi, W., Wang, D. Empirical research on the application of AI mock interviews in enhancing graduate',
#   'graduate perceived employability: a',
#   'case study in Hangzhou, China.  Educ Inf Technol  (2025) [17]. This study investigates the',
#   'the effectiveness of AI -powered mock',
#   'interviews in enhancing the perceived employability of university graduates in Hangzhou, China.',
#   'China. Amid st a competitive job market',
#   'and increasing graduate numbers, the research aims to de termine whether AI -driven interview',
#   "interview simulations can bolster graduates'",
#   'confidence and readiness for employment. Participants reported a significant increase in their self',
#   'self -assessed employability after',
#   'undergoing AI mock interviews. The AI simulations contri buted to better performance in actual',
#   'in actual interview scenarios, suggesting',
#   'practical benefits beyond self-perception.',
#   'Also, sites like Interviewsby.ai show the growing demand for artificial intelligence -based mock',
#   'mock interviewing sessions. The site',
#   'provides topic -specific questions and provides user performance feedback based on AI. Efficient as',
#   'as they may be, mos t such',
#   'comparable sites are proprietary or do not support full multimodal testing. Prepmania addresses',
#   'addresses this requirement by combining real-',
#   'time question gene ration, body language monitoring, vocal analysis, and answer comparison in an',
#   'in an open, web -based environment',
#   'exclusively for students and job seekers.',
#   'Together, these studies identify the increasing ability of artificial intelligence to enhance',
#   'enhance interv iew read iness and provide key',
#   'lessons on which Prepmania is founded.',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3463',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   'III. SYSTEM ARCHITECTURE',
#   'Fig. 1 System Architecture of Prepmania',
#   'The PrepMania design is carefully  crafted to provide an AI-driven smooth mock interview experience',
#   'to practice,',
#   'receive immediate feedback, and track improvement over time. The key components and stages of the',
#   'of the system are outlined below:',
#   '1. User Authentication \n- Sign In: Users securely log in to access their personalized dashboard.',
#   '2. Dashboard Access: After login, users are directed to a centralized dashboard where they can:',
#   '- Initiate a new interview. \n3. Interview Setup: Users start by providing essential details:',
#   '- Job Role \n- Key Skills \n- Years of Experience \n4.Start Interview:',
#   '- After filling in the details, users proceed to initiate the mock interview.',
#   '5. Question Fetching',
#   '- Dynamic Question Generation: Interview questions are automatically fetched from the Gemini API,',
#   'API, and tailored to the job',
#   'role, skills, and experience entered by the user. \n6. Answer Recording and Monitoring',
#   '- Display Questions: Questions are presented one by one for the user to answer.',
#   '- Answer Recording: Users record their spoken answers, while the system simultaneously:',
#   'o Converts speech-to-text using Speech-to-Text technology.',
#   'o Monitors body posture and hand gestures using MediaPipe models.',
#   'o Provides real-time prompts if improper posture or hand obstruction is detected.',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3464',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   '7. Feedback Generation',
#   '- AI-Based Analysis:  Each recorded answer is sent to the Gemini API , where AI evaluates the',
#   'the content and g enerates',
#   'structured feedback on: \no Relevance \no Clarity \no Confidence \n8. Data Storage',
#   '- Database Integration: All user data is securely stored in a Neon PostgreSQL database through',
#   'through Drizzle ORM, including:',
#   'o Interview metadata \no Transcribed answers \no AI-generated feedback \n9. Feedback Display',
#   '- Comprehensive Feedback Review: Upon completion of the interview, users receive detailed insights',
#   'insights regarding:',
#   'o Answer quality \no Body language observations \no Performance trends compared to previous sessions',
#   '10. Session Completion',
#   '- Return to Dashboard: After reviewing feedback, users can return to the Dashboard to start new',
#   'start new interviews or monitor',
#   'progress over time. \n \nFlowchart',
#   'Fig 2: Flowchart of Prepmania',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3465',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   'IV. METHODOLOGY \n1) System Design: Prepmania uses a full-stack architecture:',
#   '- Frontend: Built with Next.js and styled using Tailwind CSS for a responsive UI.',
#   '- Backend: Handles API integrations, data processing, and scoring logic.',
#   '- Database: Drizzle ORM with Neon stores user data and performance records.',
#   '2) Authentication : User login and session management are powered by Clerk (Clerk Authentication is',
#   'is a modern, developer -',
#   'friendly authentication and user management service designed for web and mobile apps. It provides a',
#   'a complete set of features',
#   'out of the box including) enabling secure access and personalized interview tracking.',
#   '3) Dynamic Question Generation : Questions are generated using the Gemini API, based on user input',
#   'input (job role, skills, experience).',
#   'Responses are saved for future comparisons. \n4) Audio-Visual Analysis',
#   '- Voice: Analyzes volume and clarity using Web Audio API.',
#   '- Posture: Tracks body posture using browser -based tools (e.g., face -api.js, MediaPipe).',
#   'Suggestions are provided',
#   'based on heuristics.',
#   '5) Answer Evaluation : User responses are transcribed and compared to Gemini-generated answers',
#   'answers using keyword matching and',
#   'structure checks. A score is assigned based on similarity.',
#   '6) Performance Feedback : Users receive feedback via:',
#   '- Visuals: Charts showing a comparison of past and current interview performance.',
#   '- Keyword Suggestions: Tips for improving delivery and presence.',
#   '7) Timed Question Flow : Each question has a timer. If unanswered, the system automatically moves',
#   'moves to th e next question. Timing',
#   'data is logged for analysis.',
#   '8) Data Management : All user data, responses, and perfor mance metrics are securely stored in Neon',
#   'in Neon and managed via Drizzle',
#   'ORM for efficient access and progress tracking. \n \nV. RESULTS AND EVALUATION',
#   'This table provides a performance analysis of an AI mock interview system across four batches (A,',
#   '(A, B,  C, D), with each batch',
#   "consisting of 25 students. The system's effectiveness is evaluated on several key metrics:",
#   '1) System Performance: This includes the average question generation time and page load time for',
#   'time for each b atch. The system',
#   'consistently performs with an average question generation time of around 1.8 seconds and page load',
#   'page load times under 2 seconds.',
#   '2) Question Quality: The relevance and balance of questions are assessed, with batches showing high',
#   'high rel evance ratings (ranging',
#   'from 90% to 94%) and a well-balanced mix of technical and behavioral questions across all groups.',
#   '3) Audio-Visual Analysis: The system tracks voice clarity, volume accuracy, and facial',
#   'facial expression/posture to evaluate non-verbal',
#   'communication. The accuracy of voice volume and facial expression analysis ranges fr om 81% to 85%,',
#   'to 85%, showing effectiveness',
#   'in monitoring user confidence and communication.',
#   '4) Answer Scoring: The system’s ability to evaluate answers is compared with human evaluation,',
#   'achievin g high correlation',
#   'scores (around 90% to 92%), indicating accurate assessments of the students’ responses.',
#   '5) User Progress:  \nProgress is measured in three areas:',
#   '\uf06c Voice Consistency: Improvements in maintaining voice clarity.',
#   '\uf06c Answer Accuracy: Enhancement in the accuracy of responses.',
#   '\uf06c Confidence/Posture: Improvements in overall i nterview confidence and body language. Users show',
#   'show average',
#   'improvements of 14% to 22% across these areas.',
#   "6) User Feedback: After completing the mock interview, students provide feedback on the system's",
#   "system's usabil ity. Satisfaction ratings",
#   "range from 4.5 to 4.7 ou t of 5, with students appreciating the system's ease of use and features",
#   'features like timed flow and visual',
#   'feedback.',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3466',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   'Category Metric Batch A \n(n=25) \nBatch B \n(n=25) \nBatch C \n(n=25) \nBatch D \n(n=25) \nOverall /',
#   'System Avg \nSystem \nPerformance \nAvg. Question \nGeneration Time \n(sec) \n1.9 1.7 1.8 1.8 1.8 sec',
#   'Avg. Page Load \nTime (sec) 2.0 1.9 1.8 1.7 < 2 sec \nQuestion \nQuality \nRelevance Rating',
#   '(Avg %) 90% 93% 91% 94% 92% \nA mix of Technical \n& Behavioral High High High High ✔ Balanced',
#   'Audio-Visual \nAnalysis \nVoice Volume & \nClarity Accuracy 81% 83% 82% 82% 82% \nFacial/Posture',
#   'Suggestion \nEffectiveness \n80% 85% 82% 83% 80–85% \nAnswer \nScoring \nCorrelation with',
#   'Human Evaluation 90% 91% 92% 91% 91% \nUser Progress \nVoice Consistency',
#   'Improvement +15% +17% +16% +16% +16% \nAnswer Accuracy \nImprovement +20% +22% +21% +21% +21%',
#   'Confidence/ \nPosture \nImprovement \n+13% +15% +14% +14% +14% \nUser Feedback \nSatisfaction Rating',
#   '(out of 5) 4.5 4.6 4.6 4.7 4.6 / 5 \nEase of Use (out of \n5) 4.6 4.7 4.7 4.8 4.7 / 5 \nTimed Flow &',
#   'Visual Feedback \nAppreciated by \nall \n Appreciated by \nall \nAppreciated by \nall \nAppreciated by',
#   'all \n✔ Highly \nAppreciated \nTable 1 : Analysis of assessment conducted',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3467',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   'In summary, the analysis shows that the AI mock interview system is effective in improving',
#   'improving interview performance, with consistent',
#   'system performance, high -quality questions, accurate assessments, and significant improvements in',
#   'in student skills, all backed by',
#   'positive user feedback.',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3468',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   'Fig 3 : Graphical Representation \n \nVI. SNAPSHOTS \n \n \nSnapshot 1 : Question Section',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3469',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   'Snapshot 2 : Analysis of previous & current mock interview',
#   'Snapshot 3 : Feedback from Gemini AI & user answer \n \nVI. CONCLUSION',
#   'The article covered Prepmania, a web -based mock interview platform developed with Next.js in',
#   'in conjunction with a contemporary',
#   'frontend/backend tech stack. The platform combines functionalities such as question creation,',
#   'creation, multim odal analysis, visualization of',
#   'performance, and timed evaluations to provide immersive and educational interview practice.',
#   'practice. Prospect ive future enhancements',
#   'could involve a boost in real-time processing, broader API coverage, and support for adaptive',
#   'adaptive difficulty in questions.',
#   'REFERENCES',
#   '[1] S. Kolpe, S. Patil, J. Deshmukh, S. Jeughale, and Y. Misal, "AI -Based Mock - Interview',
#   'Interview Behavioural Recognition A nalyst," International Journal for Research',
#   'in Applied Science and Engineering Technology (IJRASET), May 2024. [Online]. Available:',
#   'https://doi.org/10.22214/ijraset.2024.61427',
#   'International Journal for Research in Applied Science & Engineering Technology (IJRASET)',
#   'ISSN:',
#   'ISSN: 2321-9653; IC Value: 45.98; SJ Impact Factor: 7.538',
#   'Volume 13 Issue V May 2025- Available at www.ijraset.com',
#   '3470',
#   '©IJRASET: All Rights are Reserved | SJ Impact Factor 7.538 | ISRA Journal Impact Factor 7.894 |',
#   '[2] S. Rai, A. Miranda, S. Jagirdar, and N. Chitalia, “Skillup Bot: An AI Driven Mock Interview',
#   'Interview Platform,” IRJET, Apr.2024. [Online].',
#   'Available:https://www.irjet.net/archives/V11/i4/IRJET -V11I4385.pdf',
#   '[3] A. Katakar, N. Kadam, S. Jagtap, and P. Hole, “Mock Interview System Using AI,”',
#   'AI,”  IRJMETS,Oct.2024.[Online].Available:',
#   'https://www.doi.org/10.56726/IRJMETS6240',
#   '[4] H. R. Agashe, D. Anwat, P. Derle, P. Nagare, and S. Dhavale, "AI -Based Mock Interview',
#   'Interview Evaluator and Analysis," IJARSCT, Nov. 2023. [Online]. Available:',
#   'https://ijarsct.co.in/Paper13645.pdf',
#   '[5] Balasaheb Jadhav ; Avadhut Sawant ; Arnav Shah ; Pranamya Vemula ; Abhijeet Waikar ; Srushti',
#   '; Srushti Yadav  “ A Comprehensive Study and Implementation of the',
#   'Mock Interview Simulator with AI and Pose -Based Interaction” [online] Available:',
#   'https://ieeexplore.ieee.org/document/10530717',
#   '[6] Bharati Thawali , Pranjal Kalal, Samarth Dugam, Harshada Lokhande. “EmoConfident Interviewer',
#   ':An AI Mock Interview Evaluato ” [online]  Available:',
#   'https://www.ijraset.com/research -paper/emo-confident-interviewer-an-ai-mock-interview-evaluator',
#   '[7] Mr. Shivam Mangesh Patil, Mr. Kapil Vikas Shinde, Mr.  Bhavesh Ganesh Vakare, Mr. Sandesh',
#   'Sandesh Sanjay Dunbale  “AI Powered Mock Interview Platform ”',
#   '[online] . Available: https://www.ijirmps.org/research -paper.php?id=231993',
#   '[8] Latham, G. P., and Saari , L. M. (1984). “Applicant reactions to employment  interviews: A',
#   'A review of the  literature and research agenda. Journal of Applied',
#   'Psychology” 69(3), 400-410.[online] Available: https://issuu.com/irjet/docs/irjet -v11i1230',
#   '[9] McCarthy, J. D., Goffin, R. D., and  Kelloway, E. K.  (2020). The role of technology in',
#   'in interview  preparation. Human Resource Management Review,  30(4),',
#   '100-112. [online] Available: https://www.irjet.net/archives/V11/i12/IRJET -V11I1230.pdf',
#   '[10] Binns, R. S., Johnson, D., and Zhou, X. (2021).  “Artificial Intelligence in career',
#   'in career development and job  matching. AI and Society, 36(2), 371 -385. , S. A., and',
#   'Imber, A. (2007). The effects of simulat ed interview  practice on performance.  International',
#   'Journal of  Selection and Assessment, 15(1), 32 -42. [online]',
#   'Available: https://www.irjet.net/archives/V11/i12/IRJET -V11I1230.pdf',
#   '[11] Allen, D. G., and Ryan, A. M. (2003). Feedback and  performance improvement: A review of the',
#   'of the literature.Organizational Behavior and Human Decision',
#   'Processes, 91(2),186207. [online]Available:',
#   'https://www.researchgate.net/publication/2855681_Organizational_Behavior_and_Human_Decision_Process',
#   'on_Processe',
#   's',
#   '[12] https://ieeexplore.ieee.org/document/10760 210',
#   '[13]',
#   'https://www.researchgate.net/publication/390438737_Empirical_research_on_the_application_of_AI_mock',
#   'of_AI_mock_',
#   'interviews_in_enhancing_graduate_perceived_em',
#   'ployability_a_case_study_in_Hangzhou_China  \n[14] https://dl.acm.org/doi/10.1145/3701188',
#   '[15] https://open-publishing.org/journals/index.php/jutlp/article/view/738'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'page': 0,
#    'page_label': '1',
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12},
#   {'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'page': 1,
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'page_label': '2',
#    'producer': 'FPDF 1.82'},
#   {'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'page': 1,
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page_label': '2',
#    'total_pages': 12},
#   {'total_pages': 12,
#    'page': 1,
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page_label': '2',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF'},
#   {'page_label': '2',
#    'page': 1,
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137'},
#   {'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'page_label': '2',
#    'page': 1},
#   {'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'page': 1,
#    'page_label': '2',
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf'},
#   {'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'page_label': '2',
#    'creator': 'PyPDF',
#    'page': 1,
#    'total_pages': 12},
#   {'producer': 'FPDF 1.82',
#    'page': 1,
#    'creationdate': 'D:20250911155137',
#    'page_label': '2',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf'},
#   {'page_label': '2',
#    'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'page': 1},
#   {'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'creator': 'PyPDF',
#    'page_label': '2',
#    'page': 1,
#    'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137'},
#   {'page_label': '2',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'page': 1,
#    'producer': 'FPDF 1.82',
#    'total_pages': 12},
#   {'creator': 'PyPDF',
#    'page_label': '2',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'page': 1,
#    'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137'},
#   {'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'page': 1,
#    'total_pages': 12,
#    'page_label': '2'},
#   {'page': 1,
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'page_label': '2',
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12},
#   {'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'page': 1,
#    'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'page_label': '2',
#    'source': '../Data/RP1.pdf'},
#   {'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'page_label': '2',
#    'creator': 'PyPDF',
#    'page': 1},
#   {'producer': 'FPDF 1.82',
#    'page_label': '2',
#    'page': 1,
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12},
#   {'total_pages': 12,
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page': 1,
#    'source': '../Data/RP1.pdf',
#    'page_label': '2'},
#   {'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'page': 1,
#    'page_label': '2',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137'},
#   {'total_pages': 12,
#    'creator': 'PyPDF',
#    'page_label': '2',
#    'page': 1,
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137'},
#   {'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'page': 1,
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'page_label': '2'},
#   {'page': 1,
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'page_label': '2',
#    'total_pages': 12},
#   {'page': 1,
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'page_label': '2',
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12},
#   {'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'page': 1,
#    'page_label': '2',
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF'},
#   {'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'page_label': '2',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'page': 1},
#   {'page_label': '2',
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'page': 1,
#    'total_pages': 12},
#   {'creationdate': 'D:20250911155137',
#    'page_label': '2',
#    'page': 1,
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'total_pages': 12},
#   {'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'page_label': '2',
#    'total_pages': 12,
#    'creator': 'PyPDF',
# ...
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'page': 7},
#   {'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'page_label': '8',
#    'creator': 'PyPDF',
#    'page': 7,
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12},
#   {'creationdate': 'D:20250911155137',
#    'page_label': '8',
#    'page': 7,
#    'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF'},
#   {'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'page': 7,
#    'producer': 'FPDF 1.82',
#    'page_label': '8',
#    'creationdate': 'D:20250911155137'},
#   {'producer': 'FPDF 1.82',
#    'page_label': '8',
#    'page': 7,
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf'},
#   {'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'page_label': '8',
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'page': 7,
#    'creator': 'PyPDF'},
#   {'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'page_label': '8',
#    'page': 7},
#   {'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'page_label': '8',
#    'page': 7,
#    'source': '../Data/RP1.pdf'},
#   {'creator': 'PyPDF',
#    'page_label': '8',
#    'producer': 'FPDF 1.82',
#    'page': 7,
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf'},
#   {'page': 7,
#    'creationdate': 'D:20250911155137',
#    'page_label': '8',
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12},
#   {'page': 7,
#    'producer': 'FPDF 1.82',
#    'page_label': '8',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'total_pages': 12},
#   {'creator': 'PyPDF',
#    'total_pages': 12,
#    'page': 8,
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'page_label': '9',
#    'creationdate': 'D:20250911155137'},
#   {'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'page': 8,
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'page_label': '9'},
#   {'page': 8,
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page_label': '9',
#    'creator': 'PyPDF'},
#   {'page_label': '9',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'page': 8,
#    'creator': 'PyPDF'},
#   {'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'page_label': '9',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'page': 8},
#   {'creationdate': 'D:20250911155137',
#    'page': 8,
#    'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'page_label': '9'},
#   {'total_pages': 12,
#    'page': 8,
#    'creator': 'PyPDF',
#    'page_label': '9',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82'},
#   {'page_label': '10',
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'page': 9},
#   {'page': 9,
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'page_label': '10'},
#   {'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'page': 9,
#    'page_label': '10',
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82'},
#   {'creationdate': 'D:20250911155137',
#    'page': 9,
#    'page_label': '10',
#    'total_pages': 12,
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82'},
#   {'page': 9,
#    'page_label': '10',
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'total_pages': 12},
#   {'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'page': 9,
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'page_label': '10'},
#   {'page': 9,
#    'producer': 'FPDF 1.82',
#    'page_label': '10',
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12},
#   {'total_pages': 12,
#    'page_label': '10',
#    'page': 9,
#    'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf'},
#   {'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'page_label': '10',
#    'page': 9,
#    'creationdate': 'D:20250911155137'},
#   {'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'page_label': '10',
#    'total_pages': 12,
#    'page': 9,
#    'producer': 'FPDF 1.82'},
#   {'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'page': 9,
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'page_label': '10'},
#   {'creator': 'PyPDF',
#    'page': 9,
#    'creationdate': 'D:20250911155137',
#    'page_label': '10',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf'},
#   {'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'page_label': '10',
#    'page': 9},
#   {'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'page_label': '10',
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page': 9,
#    'total_pages': 12},
#   {'page': 9,
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'page_label': '10',
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12},
#   {'page': 9,
#    'creator': 'PyPDF',
#    'page_label': '10',
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12},
#   {'producer': 'FPDF 1.82',
#    'page_label': '10',
#    'source': '../Data/RP1.pdf',
#    'page': 9,
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF'},
#   {'creator': 'PyPDF',
#    'page': 9,
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'page_label': '10',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82'},
#   {'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'page_label': '10',
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'page': 9},
#   {'page': 9,
#    'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'page_label': '10',
#    'total_pages': 12,
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf'},
#   {'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf',
#    'page': 9,
#    'creator': 'PyPDF',
#    'page_label': '10'},
#   {'page_label': '11',
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'page': 10,
#    'producer': 'FPDF 1.82',
#    'total_pages': 12},
#   {'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'page': 10,
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'page_label': '11'},
#   {'creationdate': 'D:20250911155137',
#    'page_label': '11',
#    'page': 10,
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf'},
#   {'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'page': 10,
#    'page_label': '11',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12},
#   {'total_pages': 12,
#    'page': 10,
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'page_label': '11',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82'},
#   {'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'page_label': '11',
#    'total_pages': 12,
#    'page': 10},
#   {'creator': 'PyPDF',
#    'page_label': '11',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page': 10,
#    'source': '../Data/RP1.pdf'},
#   {'page': 10,
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'creator': 'PyPDF',
#    'page_label': '11'},
#   {'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'page': 10,
#    'page_label': '11',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'creator': 'PyPDF'},
#   {'page': 10,
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'page_label': '11',
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf'},
#   {'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'page_label': '11',
#    'page': 10,
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82'},
#   {'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'page': 10},
#   {'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'page': 10,
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'total_pages': 12},
#   {'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'total_pages': 12,
#    'page': 10},
#   {'creationdate': 'D:20250911155137',
#    'page_label': '11',
#    'total_pages': 12,
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'page': 10,
#    'source': '../Data/RP1.pdf'},
#   {'total_pages': 12,
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'page_label': '11',
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'page': 10},
#   {'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'page_label': '11',
#    'creator': 'PyPDF',
#    'page': 10,
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12},
#   {'creationdate': 'D:20250911155137',
#    'page_label': '11',
#    'creator': 'PyPDF',
#    'page': 10,
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12},
#   {'source': '../Data/RP1.pdf',
#    'page_label': '11',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page': 10},
#   {'page_label': '11',
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'page': 10},
#   {'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'source': '../Data/RP1.pdf',
#    'page': 10,
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137'},
#   {'page_label': '11',
#    'creator': 'PyPDF',
#    'page': 10,
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12},
#   {'producer': 'FPDF 1.82',
#    'page': 10,
#    'total_pages': 12,
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'page_label': '11'},
#   {'page': 10,
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf'},
#   {'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'page_label': '11',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'page': 10,
#    'creator': 'PyPDF'},
#   {'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'page_label': '11',
#    'page': 10,
#    'creationdate': 'D:20250911155137'},
#   {'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'page_label': '11',
#    'total_pages': 12,
#    'page': 10,
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf'},
#   {'page': 10,
#    'page_label': '11',
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'producer': 'FPDF 1.82'},
#   {'page': 10,
#    'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf'},
#   {'page': 10,
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'page_label': '11',
#    'producer': 'FPDF 1.82'},
#   {'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf',
#    'page_label': '11',
#    'creator': 'PyPDF',
#    'page': 10},
#   {'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'page_label': '11',
#    'creator': 'PyPDF',
#    'page': 10,
#    'producer': 'FPDF 1.82',
#    'total_pages': 12},
#   {'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'page': 10,
#    'page_label': '11',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12},
#   {'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'page': 10,
#    'creator': 'PyPDF',
#    'page_label': '11',
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137'},
#   {'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'page_label': '11',
#    'source': '../Data/RP1.pdf',
#    'page': 10},
#   {'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf',
#    'creator': 'PyPDF',
#    'page': 10,
#    'total_pages': 12},
#   {'total_pages': 12,
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'page': 10,
#    'page_label': '11',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf'},
#   {'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'page': 10,
#    'page_label': '11',
#    'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12},
#   {'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'page': 10,
#    'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'total_pages': 12},
#   {'page_label': '11',
#    'page': 10,
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'source': '../Data/RP1.pdf'},
#   {'total_pages': 12,
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'creator': 'PyPDF',
#    'page_label': '11',
#    'producer': 'FPDF 1.82',
#    'page': 10},
#   {'total_pages': 12,
#    'page': 10,
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82',
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'page_label': '11'},
#   {'creator': 'PyPDF',
#    'source': '../Data/RP1.pdf',
#    'page': 10,
#    'creationdate': 'D:20250911155137',
#    'total_pages': 12,
#    'producer': 'FPDF 1.82',
#    'page_label': '11'},
#   {'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'page': 10,
#    'page_label': '11',
#    'creator': 'PyPDF'},
#   {'creator': 'PyPDF',
#    'total_pages': 12,
#    'page': 10,
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'creationdate': 'D:20250911155137',
#    'page_label': '11'},
#   {'page_label': '11',
#    'source': '../Data/RP1.pdf',
#    'producer': 'FPDF 1.82',
#    'creator': 'PyPDF',
#    'total_pages': 12,
#    'creationdate': 'D:20250911155137',
#    'page': 10},
#   {'page_label': '11',
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf',
#    'creationdate': 'D:20250911155137',
#    'page': 10,
#    'creator': 'PyPDF',
#    'producer': 'FPDF 1.82'},
#   {'creator': 'PyPDF',
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'page': 10,
#    'total_pages': 12,
#    'source': '../Data/RP1.pdf'},
#   {'total_pages': 12,
#    'creator': 'PyPDF',
#    'page': 10,
#    'creationdate': 'D:20250911155137',
#    'producer': 'FPDF 1.82',
#    'page_label': '11',
#    'source': '../Data/RP1.pdf'}]}

# %%
vector_store.similarity_search('tell me about the system architecture',k=3)
# Out:
# [Document(metadata={'creationdate': 'D:20250911155137', 'page': 3, 'producer': 'FPDF 1.82', 'creator': 'PyPDF', 'total_pages': 12, 'page_label': '4', 'source': '../Data/RP1.pdf'}, page_content='III. SYSTEM ARCHITECTURE'),
#  Document(metadata={'page_label': '6', 'creator': 'PyPDF', 'creationdate': 'D:20250911155137', 'page': 5, 'total_pages': 12, 'producer': 'FPDF 1.82', 'source': '../Data/RP1.pdf'}, page_content='IV. METHODOLOGY \n1) System Design: Prepmania uses a full-stack architecture:'),
#  Document(metadata={'page_label': '4', 'page': 3, 'creator': 'PyPDF', 'source': '../Data/RP1.pdf', 'creationdate': 'D:20250911155137', 'total_pages': 12, 'producer': 'FPDF 1.82'}, page_content='Fig. 1 System Architecture of Prepmania')]
